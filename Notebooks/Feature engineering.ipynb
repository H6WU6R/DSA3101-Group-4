# %%
import pandas as pd
import numpy as np
import json
from scipy.sparse import csr_matrix, identity
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from lightfm import LightFM
from lightfm.evaluation import precision_at_k, auc_score
from sklearn.metrics import accuracy_score, f1_score
import itertools
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA

# %% [markdown]
# ### Load data

# %%
df_imputed_original = pd.read_csv('../data/processed/imputed_data_with_label.csv')

# %% [markdown]
# ### Perform PCA on existing data

# %%
target_cols = ['Automotive & Transportation Services', 'Clothing & Fashion',
       'Digital Goods & Computers', 'Electronics & Appliances',
       'Freight & Trucking', 'Hotels & Accommodation',
       'Legal & Financial Services', 'Machinery & Tools',
       'Medical & Healthcare Services', 'Movies & Theaters',
       'Postal Services - Government Only', 'Rail & Bus Transport',
       'Restaurants & Eating Places', 'Retail Stores',
       'Sports & Recreational Activities', 'Steel & Metal Products',
       'Telecommunications & Media', 'Utilities & Home Services']

# List of feature columns used for imputation
feature_cols = ['current_age', 'retirement_age', 'birth_month', 'gender',
       'latitude', 'longitude', 'yearly_income', 'total_debt', 'credit_score',
       'num_credit_cards', 'Credit', 'Debit', 'Debit (Prepaid)']

label_cols = ['Label_Rewards_Credit_Card', 'Label_Insurance_Solutions',
              'Label_Digital_Financing', 'Label_Home_Improvement_Loan',
              'Label_Auto_Vehicle_Financing', 'Label_Commodity_Investment_Services',
              'Label_Travel_Rewards_Card', 'Label_Savings_Investment_Plans',
              'Label_Wealth_Management_Savings']

Y = df_imputed_original[label_cols].copy()
Y_bin = (Y >= 2).astype(int)

# Prepare user features for tuning.
# Define two feature sets:
base_features = feature_cols.copy()
expanded_features = feature_cols + target_cols  # expanded: include spending categories

# %%
def compute_top3_accuracy_for_fold(model, X_val, interactions_val, item_features, k=3):
    num_users = X_val.shape[0]
    top3_acc = []
    users_with_purchases = 0  # Track users who actually bought something
    
    for user_id in range(num_users):
        # Predict scores for all items for this user
        scores = model.predict(user_id, np.arange(interactions_val.shape[1]),
                             user_features=X_val,
                             item_features=item_features)
        
        # Get top k predicted item indices
        top3_indices = np.argsort(-scores)[:k]
        
        # Get true purchased item indices
        true_positives = set(np.where(interactions_val[user_id].toarray().flatten() == 1)[0])
        n_true = len(true_positives)
        
        # Skip users with no purchases (do not count them in accuracy)
        if n_true == 0:
            continue
        
        users_with_purchases += 1
        
        # Case 1: User purchased 3+ items
        if n_true >= 3:
            count = len(set(top3_indices).intersection(true_positives))
            top3_acc.append(count / 3.0)
        
        # Case 2: User purchased exactly 2 items
        elif n_true == 2:
            intersection = set(top3_indices).intersection(true_positives)
            if len(intersection) == 2:
                top3_acc.append(1.0)
            elif len(intersection) == 1:
                top3_acc.append(0.5)
            else:
                top3_acc.append(0)
        
        # Case 3: User purchased exactly 1 item
        elif n_true == 1:
            if top3_indices[0] in true_positives:
                top3_acc.append(1.0)
            elif len(set(top3_indices[1:]).intersection(true_positives)) > 0:
                top3_acc.append(0.5)
            else:
                top3_acc.append(0)
    
    # Return 0 if no users made purchases (edge case)
    if users_with_purchases == 0:
        return 0.0
    
    return np.mean(top3_acc)

# %%
def grid_search_cv(feature_list, X_train_full, Y_train_bin):
    # Extract the features from X_train_full based on the provided feature list.
    X_train_features = X_train_full[feature_list].copy()
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_features)
    user_features = csr_matrix(X_train_scaled)
    
    # Build the interaction matrix from Y_train_bin.
    interactions = csr_matrix(Y_train_bin.values)
    num_items = interactions.shape[1]
    item_features = identity(num_items, format='csr')
    
    # Define hyperparameter grid.
    param_grid = {
        'loss': ['warp', 'bpr','logistic'],
        'no_components': [16, 32, 64],
        'learning_rate': [0.001, 0.01, 0.05],
        'epochs': [30, 50],
        'user_alpha': [1e-5, 1e-4],
        'item_alpha': [1e-5, 1e-4]
    }
    
    # Set up 5-fold CV.
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    grid_results = []
    upsample_factor = 2

    for loss, no_components, learning_rate, epochs, user_alpha, item_alpha in itertools.product(
        param_grid['loss'],
        param_grid['no_components'],
        param_grid['learning_rate'],
        param_grid['epochs'],
        param_grid['user_alpha'],
        param_grid['item_alpha']
    ):
        fold_top3_acc = []
        fold_prec = []

        for train_idx, val_idx in kf.split(user_features):
            X_train_cv = user_features[train_idx]
            X_val_cv = user_features[val_idx]
            
            # Get the training interactions for this fold.
            fold_train = interactions[train_idx].toarray().astype(float)
            
            # Upsample the minority class for each product column in the training fold.
            for j in range(fold_train.shape[1]):
                pos_count = np.sum(fold_train[:, j] == 1)
                neg_count = np.sum(fold_train[:, j] == 0)
                if pos_count / fold_train.shape[0] < 0.3:
                    fold_train[:, j] = np.where(fold_train[:, j] == 1,
                                                fold_train[:, j] * upsample_factor,
                                                fold_train[:, j])
                elif neg_count / fold_train.shape[0] < 0.3:
                    fold_train[:, j] = np.where(fold_train[:, j] == 0,
                                                fold_train[:, j] * upsample_factor,
                                                fold_train[:, j])
            fold_train_sparse = csr_matrix(fold_train)
            
            # Validation interactions (untouched).
            fold_val = interactions[val_idx].toarray()
            fold_val_sparse = csr_matrix(fold_val)
            
            # Train LightFM on this fold.
            model_cv = LightFM(loss=loss, no_components=no_components,
                               learning_rate=learning_rate,
                               user_alpha=user_alpha,
                               item_alpha=item_alpha,
                               random_state=42)
            model_cv.fit(fold_train_sparse,
                         user_features=X_train_cv,
                         item_features=item_features,
                         epochs=epochs,
                         num_threads=4)
            
            # Standard precision@3.
            prec = precision_at_k(model_cv, fold_val_sparse,
                                  user_features=X_val_cv,
                                  item_features=item_features,
                                  k=3).mean()
            # Compute custom top-3 accuracy using our function.
            top3_acc = compute_top3_accuracy_for_fold(model_cv, X_val_cv, fold_val_sparse, item_features, k=3)
            
            fold_top3_acc.append(top3_acc)
            fold_prec.append(prec)
        
        avg_top3_acc = np.mean(fold_top3_acc)
        avg_prec = np.mean(fold_prec)
        
        grid_results.append({
            'loss': loss,
            'no_components': no_components,
            'learning_rate': learning_rate,
            'epochs': epochs,
            'user_alpha': user_alpha,
            'item_alpha': item_alpha,
            'top3_accuracy': avg_top3_acc,
            'precision@3': avg_prec
        })
        
        print(f"Params: loss={loss}, components={no_components}, "
              f"lr={learning_rate}, epochs={epochs}, user_alpha={user_alpha}, item_alpha={item_alpha} -> "
              f"Top3 Accuracy: {avg_top3_acc:.4f}, Precision@3: {avg_prec:.4f}")
    
    best_params = max(grid_results, key=lambda x: x['top3_accuracy'])
    return best_params, grid_results

# %%
def evaluate_lightfm_model(X_train_full, X_test, Y_train_bin, Y_test_bin, feature_set, best_params, label_cols):
    # 1. Feature Selection and Standardization
    X_train_selected = X_train_full[feature_set].copy()
    X_test_selected = X_test[feature_set].copy()
    
    scaler_final = StandardScaler()
    X_train_final = scaler_final.fit_transform(X_train_selected)
    X_test_final = scaler_final.transform(X_test_selected)
    
    # Convert to sparse matrices for efficiency
    user_features_train_final = csr_matrix(X_train_final)
    user_features_test_final = csr_matrix(X_test_final)

    # 2. Prepare Interaction Data
    final_interactions_train = csr_matrix(Y_train_bin.values)
    final_interactions_test = csr_matrix(Y_test_bin.values)
    num_items = len(label_cols)
    final_item_features = identity(num_items, format='csr')

    # 3. Train Final Model with Best Parameters
    model_final = LightFM(
        loss=best_params['loss'],
        no_components=best_params['no_components'],
        learning_rate=best_params['learning_rate'],
        user_alpha=best_params['user_alpha'],
        item_alpha=best_params['item_alpha'],
        random_state=42
    )

    model_final.fit(
        final_interactions_train,
        user_features=user_features_train_final,
        item_features=final_item_features,
        epochs=best_params['epochs'],
        num_threads=4
    )

    # 4. Evaluation Metrics
    # Precision@3
    final_precision = precision_at_k(
        model_final,
        final_interactions_test,
        user_features=user_features_test_final,
        item_features=final_item_features,
        k=3
    ).mean()

    # Custom Top-3 Accuracy
    custom_top3_accuracy = compute_top3_accuracy_for_fold(
        model_final, 
        user_features_test_final, 
        final_interactions_test, 
        final_item_features, 
        k=3
    )

    # 5. Generate Recommendations (Key Part)
    top3_recommendations = {}
    for user_id in range(user_features_test_final.shape[0]):
        # Predict scores for all items
        scores = model_final.predict(
            user_id, 
            np.arange(num_items),
            user_features=user_features_test_final,
            item_features=final_item_features
        )
        
        # Get indices of top 3 highest scores
        top3_indices = np.argsort(-scores)[:3]
        
        # Map indices to product names
        recommended_products = [label_cols[idx] for idx in top3_indices]
        top3_recommendations[user_id] = recommended_products

    return {
        'precision@3': final_precision,
        'custom_top3_accuracy': custom_top3_accuracy
    }, top3_recommendations

# %% [markdown]
# ### Before performing PCA, we want to find the number of components that is able to explain 90% of the variance, eventually we choose n = 23.

# %%
X_expanded = df_imputed_original[expanded_features].copy()
scaler_exp = StandardScaler()
X_expanded_scaled = scaler_exp.fit_transform(X_expanded)

# Assume X_expanded_scaled is already computed (using StandardScaler on your expanded features)
n_total = X_expanded_scaled.shape[1]  # should be 40

for n in range(1, n_total + 1):
    pca_temp = PCA(n_components=n, random_state=42)
    pca_temp.fit(X_expanded_scaled)
    cum_explained = np.sum(pca_temp.explained_variance_ratio_)
    print(f"n_components = {n}: Cumulative explained variance = {cum_explained:.4f}")
# Out:
# n_components = 1: Cumulative explained variance = 0.1511
# n_components = 2: Cumulative explained variance = 0.2354
# n_components = 3: Cumulative explained variance = 0.2935
# n_components = 4: Cumulative explained variance = 0.3489
# n_components = 5: Cumulative explained variance = 0.3997
# n_components = 6: Cumulative explained variance = 0.4464
# n_components = 7: Cumulative explained variance = 0.4846
# n_components = 8: Cumulative explained variance = 0.5192
# n_components = 9: Cumulative explained variance = 0.5532
# n_components = 10: Cumulative explained variance = 0.5856
# n_components = 11: Cumulative explained variance = 0.6157
# n_components = 12: Cumulative explained variance = 0.6452
# n_components = 13: Cumulative explained variance = 0.6742
# n_components = 14: Cumulative explained variance = 0.7020
# n_components = 15: Cumulative explained variance = 0.7294
# n_components = 16: Cumulative explained variance = 0.7547
# n_components = 17: Cumulative explained variance = 0.7794
# n_components = 18: Cumulative explained variance = 0.8035
# n_components = 19: Cumulative explained variance = 0.8262
# n_components = 20: Cumulative explained variance = 0.8487
# n_components = 21: Cumulative explained variance = 0.8692
# n_components = 22: Cumulative explained variance = 0.8885
# n_components = 23: Cumulative explained variance = 0.9059
# n_components = 24: Cumulative explained variance = 0.9226
# n_components = 25: Cumulative explained variance = 0.9389
# n_components = 26: Cumulative explained variance = 0.9534
# n_components = 27: Cumulative explained variance = 0.9665
# n_components = 28: Cumulative explained variance = 0.9779
# n_components = 29: Cumulative explained variance = 0.9860
# n_components = 30: Cumulative explained variance = 0.9903
# n_components = 31: Cumulative explained variance = 0.9943
# n_components = 32: Cumulative explained variance = 0.9977
# n_components = 33: Cumulative explained variance = 1.0000

# %% [markdown]
# In our feature engineering process, we first apply Principal Component Analysis (PCA) to the original data to reduce dimensionality and capture the most significant variance in a set of orthogonal components. This initial PCA step compresses the data into a more manageable form and mitigates issues such as multicollinearity. Subsequently, we generate polynomial features based on these PCA-transformed components to capture nonlinear interactions among them. By applying polynomial transformations after PCA, we effectively model complex relationships in the data while avoiding the exponential increase in dimensionality that would occur if polynomial features were generated on the original high-dimensional dataset.
#
# Run Grid Search for PCA where `n_components=23`

# %%
pca_no_poly = PCA(n_components=23, random_state=42)  # Adjust n_components as needed.
X_pca = pca_no_poly.fit_transform(X_expanded_scaled)
pca_feature_names = [f'pca_no_poly_{i}' for i in range(X_pca.shape[1])]

df_pca_no_poly = pd.DataFrame(X_pca, columns=pca_feature_names, index=df_imputed_original.index)

final_feature_set = pca_feature_names

# Split the PCA-transformed data and binarized labels into train and test sets.
X_train_pca, X_test_pca, Y_train_bin, Y_test_bin = train_test_split(df_pca_no_poly, Y_bin, test_size=0.2, random_state=42)

print("\n--- Running grid search for PCA features (no polynomial interactions) ---")
best_params_pca, all_results_pca = grid_search_cv(final_feature_set, X_train_pca, Y_train_bin)
print(f"Best PCA params: {best_params_pca}")
# Out:
# --- Running grid search for PCA features (no polynomial interactions) ---
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7979, Precision@3: 0.6604
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7979, Precision@3: 0.6604
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7979, Precision@3: 0.6604
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7977, Precision@3: 0.6602
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8008, Precision@3: 0.6647
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8014, Precision@3: 0.6652
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8014, Precision@3: 0.6652
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8012, Precision@3: 0.6650
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8593, Precision@3: 0.7140
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8596, Precision@3: 0.7140
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8587, Precision@3: 0.7135
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8578, Precision@3: 0.7127
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8618, Precision@3: 0.7161
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8614, Precision@3: 0.7153
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8619, Precision@3: 0.7157
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8627, Precision@3: 0.7163
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8703, Precision@3: 0.7220
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8692, Precision@3: 0.7209
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8693, Precision@3: 0.7209
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8714, Precision@3: 0.7232
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8699, Precision@3: 0.7222
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8702, Precision@3: 0.7228
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8731, Precision@3: 0.7239
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8695, Precision@3: 0.7213
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7822, Precision@3: 0.6477
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7820, Precision@3: 0.6477
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7819, Precision@3: 0.6477
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7826, Precision@3: 0.6483
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7882, Precision@3: 0.6541
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7876, Precision@3: 0.6537
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7872, Precision@3: 0.6533
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7877, Precision@3: 0.6537
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8595, Precision@3: 0.7142
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8577, Precision@3: 0.7124
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8592, Precision@3: 0.7133
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8626, Precision@3: 0.7161
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8655, Precision@3: 0.7191
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8672, Precision@3: 0.7204
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8680, Precision@3: 0.7206
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8666, Precision@3: 0.7198
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8716, Precision@3: 0.7228
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8719, Precision@3: 0.7237
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8703, Precision@3: 0.7226
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8731, Precision@3: 0.7245
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8711, Precision@3: 0.7226
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8709, Precision@3: 0.7226
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8734, Precision@3: 0.7239
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8688, Precision@3: 0.7211
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7857, Precision@3: 0.6524
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7844, Precision@3: 0.6509
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7858, Precision@3: 0.6522
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7850, Precision@3: 0.6520
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7889, Precision@3: 0.6559
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7908, Precision@3: 0.6576
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7903, Precision@3: 0.6574
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7904, Precision@3: 0.6574
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8660, Precision@3: 0.7191
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8647, Precision@3: 0.7191
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8631, Precision@3: 0.7170
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8667, Precision@3: 0.7200
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8669, Precision@3: 0.7202
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8697, Precision@3: 0.7219
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8714, Precision@3: 0.7221
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8709, Precision@3: 0.7226
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8714, Precision@3: 0.7243
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8740, Precision@3: 0.7245
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8715, Precision@3: 0.7228
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8692, Precision@3: 0.7226
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8722, Precision@3: 0.7241
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8723, Precision@3: 0.7239
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8689, Precision@3: 0.7211
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8721, Precision@3: 0.7239
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7808, Precision@3: 0.6507
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7808, Precision@3: 0.6507
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7808, Precision@3: 0.6507
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7808, Precision@3: 0.6507
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7906, Precision@3: 0.6567
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7906, Precision@3: 0.6567
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7906, Precision@3: 0.6567
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7906, Precision@3: 0.6567
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8412, Precision@3: 0.6991
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8412, Precision@3: 0.6991
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8412, Precision@3: 0.6991
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8412, Precision@3: 0.6991
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8514, Precision@3: 0.7081
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8514, Precision@3: 0.7081
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8514, Precision@3: 0.7081
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8514, Precision@3: 0.7081
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8595, Precision@3: 0.7153
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8592, Precision@3: 0.7150
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8595, Precision@3: 0.7153
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8592, Precision@3: 0.7150
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8581, Precision@3: 0.7140
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8584, Precision@3: 0.7144
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8581, Precision@3: 0.7140
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8584, Precision@3: 0.7144
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7759, Precision@3: 0.6433
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7759, Precision@3: 0.6433
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7759, Precision@3: 0.6433
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7759, Precision@3: 0.6433
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7781, Precision@3: 0.6457
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7781, Precision@3: 0.6457
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7781, Precision@3: 0.6457
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7779, Precision@3: 0.6455
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8456, Precision@3: 0.7036
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8459, Precision@3: 0.7038
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8456, Precision@3: 0.7036
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8459, Precision@3: 0.7038
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8496, Precision@3: 0.7077
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8496, Precision@3: 0.7077
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8500, Precision@3: 0.7077
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8496, Precision@3: 0.7077
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8571, Precision@3: 0.7131
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8565, Precision@3: 0.7129
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8571, Precision@3: 0.7131
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8567, Precision@3: 0.7131
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8622, Precision@3: 0.7176
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8619, Precision@3: 0.7174
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8622, Precision@3: 0.7176
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8622, Precision@3: 0.7176
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7750, Precision@3: 0.6442
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7750, Precision@3: 0.6442
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7750, Precision@3: 0.6442
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7750, Precision@3: 0.6442
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7788, Precision@3: 0.6473
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7788, Precision@3: 0.6473
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7788, Precision@3: 0.6473
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7788, Precision@3: 0.6473
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8436, Precision@3: 0.7021
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8432, Precision@3: 0.7016
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8436, Precision@3: 0.7021
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8432, Precision@3: 0.7016
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8498, Precision@3: 0.7075
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8501, Precision@3: 0.7077
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8498, Precision@3: 0.7075
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8501, Precision@3: 0.7077
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8600, Precision@3: 0.7157
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8589, Precision@3: 0.7151
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8598, Precision@3: 0.7155
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8589, Precision@3: 0.7151
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8569, Precision@3: 0.7125
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8569, Precision@3: 0.7125
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8569, Precision@3: 0.7125
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8571, Precision@3: 0.7127
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7936, Precision@3: 0.6609
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7934, Precision@3: 0.6607
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7938, Precision@3: 0.6611
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7936, Precision@3: 0.6609
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7922, Precision@3: 0.6598
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7920, Precision@3: 0.6596
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7920, Precision@3: 0.6596
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7920, Precision@3: 0.6596
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8182, Precision@3: 0.6746
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8182, Precision@3: 0.6746
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8182, Precision@3: 0.6746
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8182, Precision@3: 0.6746
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8228, Precision@3: 0.6774
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8226, Precision@3: 0.6772
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8221, Precision@3: 0.6768
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8224, Precision@3: 0.6770
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8178, Precision@3: 0.6755
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8187, Precision@3: 0.6762
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8174, Precision@3: 0.6753
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8182, Precision@3: 0.6760
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8158, Precision@3: 0.6732
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8172, Precision@3: 0.6740
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8148, Precision@3: 0.6723
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8176, Precision@3: 0.6740
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7733, Precision@3: 0.6431
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7733, Precision@3: 0.6431
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7735, Precision@3: 0.6434
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7733, Precision@3: 0.6431
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7667, Precision@3: 0.6367
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7665, Precision@3: 0.6365
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7667, Precision@3: 0.6367
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7665, Precision@3: 0.6365
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8180, Precision@3: 0.6727
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8180, Precision@3: 0.6727
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8186, Precision@3: 0.6734
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8178, Precision@3: 0.6725
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8176, Precision@3: 0.6723
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8177, Precision@3: 0.6721
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8176, Precision@3: 0.6723
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8177, Precision@3: 0.6723
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8157, Precision@3: 0.6721
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8156, Precision@3: 0.6718
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8174, Precision@3: 0.6736
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8166, Precision@3: 0.6729
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8114, Precision@3: 0.6682
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8135, Precision@3: 0.6697
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8116, Precision@3: 0.6682
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8132, Precision@3: 0.6695
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7626, Precision@3: 0.6345
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7620, Precision@3: 0.6343
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7625, Precision@3: 0.6347
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7620, Precision@3: 0.6343
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7568, Precision@3: 0.6267
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7566, Precision@3: 0.6265
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7571, Precision@3: 0.6270
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7568, Precision@3: 0.6267
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8082, Precision@3: 0.6628
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8078, Precision@3: 0.6628
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8075, Precision@3: 0.6626
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8074, Precision@3: 0.6623
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8090, Precision@3: 0.6643
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8083, Precision@3: 0.6636
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8092, Precision@3: 0.6643
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8084, Precision@3: 0.6636
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8113, Precision@3: 0.6675
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8118, Precision@3: 0.6675
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8129, Precision@3: 0.6690
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8126, Precision@3: 0.6684
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8118, Precision@3: 0.6677
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8136, Precision@3: 0.6695
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8123, Precision@3: 0.6682
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8136, Precision@3: 0.6695
# Best PCA params: {'loss': 'warp', 'no_components': 64, 'learning_rate': 0.05, 'epochs': 30, 'user_alpha': 1e-05, 'item_alpha': 0.0001, 'top3_accuracy': 0.8740198582659383, 'precision@3': 0.72453296}

# %%
metrics_pca, recommendations_pca = evaluate_lightfm_model(
    X_train_pca, X_test_pca, Y_train_bin, Y_test_bin, final_feature_set, best_params_pca, label_cols
)

print("\nFinal Model Metrics using PCA on expanded data (no polynomial interactions):")
for k, v in metrics_pca.items():
    print(f"{k}: {v:.4f}")

print("\nTop 3 product recommendations for sample test users using PCA (no polynomial interactions):")
for uid in list(recommendations_pca.keys())[:5]:
    print(f"User {uid}: {recommendations_pca[uid]}")
# Out:
# Final Model Metrics using PCA on expanded data (no polynomial interactions):
# precision@3: 0.7084
# custom_top3_accuracy: 0.8674
#
# Top 3 product recommendations for sample test users using PCA (no polynomial interactions):
# User 0: ['Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card', 'Label_Insurance_Solutions']
# User 1: ['Label_Retention_Efforts', 'Label_Rewards_Credit_Card', 'Label_Insurance_Solutions']
# User 2: ['Label_Card_Upgrade', 'Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card']
# User 3: ['Label_Travel_Rewards_Card', 'Label_Card_Upgrade', 'Label_Rewards_Credit_Card']
# User 4: ['Label_Retention_Efforts', 'Label_Card_Upgrade', 'Label_Digital_Financing']

# %% [markdown]
# ### Using PCA does not gurantee better results as compared to the model without PCA, hence we try to use polynomial features

# %%
poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
X_poly = poly.fit_transform(X_expanded)
poly_feature_names = poly.get_feature_names_out(expanded_features)

scaler_poly = StandardScaler()
X_poly_scaled = scaler_poly.fit_transform(X_poly)

n_total = X_poly_scaled.shape[1]

# %% [markdown]
# ### Find number of component with 90% cumulative variance explained, in this case, n = 63, but that creates more features than original model. Hence we first experiment with n = 8, where 80% of variance explained, then we proceed with n = 63.

# %%
for n in range(1, n_total + 1):
    pca_polytemp = PCA(n_components=n, random_state=42)
    pca_polytemp.fit(X_poly_scaled)
    cum_polyexplained = np.sum(pca_polytemp.explained_variance_ratio_)
    print(f"n_components = {n}: Cumulative explained variance = {cum_polyexplained:.4f}")
    if cum_polyexplained > 0.9:
        break
# Out:
# n_components = 1: Cumulative explained variance = 0.1620
# n_components = 2: Cumulative explained variance = 0.2260
# n_components = 3: Cumulative explained variance = 0.2853
# n_components = 4: Cumulative explained variance = 0.3309
# n_components = 5: Cumulative explained variance = 0.3708
# n_components = 6: Cumulative explained variance = 0.4089
# n_components = 7: Cumulative explained variance = 0.4416
# n_components = 8: Cumulative explained variance = 0.4732
# n_components = 9: Cumulative explained variance = 0.5023
# n_components = 10: Cumulative explained variance = 0.5300
# n_components = 11: Cumulative explained variance = 0.5562
# n_components = 12: Cumulative explained variance = 0.5814
# n_components = 13: Cumulative explained variance = 0.6046
# n_components = 14: Cumulative explained variance = 0.6264
# n_components = 15: Cumulative explained variance = 0.6473
# n_components = 16: Cumulative explained variance = 0.6667
# n_components = 17: Cumulative explained variance = 0.6848
# n_components = 18: Cumulative explained variance = 0.7025
# n_components = 19: Cumulative explained variance = 0.7181
# n_components = 20: Cumulative explained variance = 0.7322
# n_components = 21: Cumulative explained variance = 0.7452
# n_components = 22: Cumulative explained variance = 0.7563
# n_components = 23: Cumulative explained variance = 0.7670
# n_components = 24: Cumulative explained variance = 0.7765
# n_components = 25: Cumulative explained variance = 0.7849
# n_components = 26: Cumulative explained variance = 0.7928
# n_components = 27: Cumulative explained variance = 0.7987
# n_components = 28: Cumulative explained variance = 0.8041
# n_components = 29: Cumulative explained variance = 0.8090
# n_components = 30: Cumulative explained variance = 0.8138
# n_components = 31: Cumulative explained variance = 0.8184
# n_components = 32: Cumulative explained variance = 0.8228
# n_components = 33: Cumulative explained variance = 0.8270
# n_components = 34: Cumulative explained variance = 0.8310
# n_components = 35: Cumulative explained variance = 0.8348
# n_components = 36: Cumulative explained variance = 0.8384
# n_components = 37: Cumulative explained variance = 0.8419
# n_components = 38: Cumulative explained variance = 0.8452
# n_components = 39: Cumulative explained variance = 0.8485
# n_components = 40: Cumulative explained variance = 0.8517
# n_components = 41: Cumulative explained variance = 0.8547
# n_components = 42: Cumulative explained variance = 0.8575
# n_components = 43: Cumulative explained variance = 0.8602
# n_components = 44: Cumulative explained variance = 0.8629
# n_components = 45: Cumulative explained variance = 0.8655
# n_components = 46: Cumulative explained variance = 0.8680
# n_components = 47: Cumulative explained variance = 0.8704
# n_components = 48: Cumulative explained variance = 0.8727
# n_components = 49: Cumulative explained variance = 0.8750
# n_components = 50: Cumulative explained variance = 0.8772
# n_components = 51: Cumulative explained variance = 0.8793
# n_components = 52: Cumulative explained variance = 0.8814
# n_components = 53: Cumulative explained variance = 0.8834
# n_components = 54: Cumulative explained variance = 0.8854
# n_components = 55: Cumulative explained variance = 0.8873
# n_components = 56: Cumulative explained variance = 0.8892
# n_components = 57: Cumulative explained variance = 0.8907
# n_components = 58: Cumulative explained variance = 0.8924
# n_components = 59: Cumulative explained variance = 0.8942
# n_components = 60: Cumulative explained variance = 0.8959
# n_components = 61: Cumulative explained variance = 0.8973
# n_components = 62: Cumulative explained variance = 0.8991
# n_components = 63: Cumulative explained variance = 0.9005

# %%
pcapoly = PCA(n_components=28, random_state=42)
X_poly_pca = pcapoly.fit_transform(X_poly_scaled)
pca_feature_names = [f'pca_{i}' for i in range(X_poly_pca.shape[1])]

# Instead of concatenating with the original expanded features, 
# we use only the PCA-transformed polynomial features as the final engineered features.
df_engineered = pd.DataFrame(X_poly_pca, columns=pca_feature_names, index=df_imputed_original.index)
final_feature_set = pca_feature_names

# -----------------------------------------------------------
# Step 5: Split the engineered data and binarized labels into train and test sets.
X_train_eng_full, X_test_eng, Y_train_bin, Y_test_bin = train_test_split(
    df_engineered, Y_bin, test_size=0.2, random_state=42
)

print("\n--- Running grid search for engineered features (using only PCA components) ---")
best_params_eng, all_results_eng = grid_search_cv(final_feature_set, X_train_eng_full, Y_train_bin)
print(f"Best engineered params: {best_params_eng}")
# Out:
# --- Running grid search for engineered features (using only PCA components) ---
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7893, Precision@3: 0.6561
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7891, Precision@3: 0.6559
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7891, Precision@3: 0.6559
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7891, Precision@3: 0.6559
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7923, Precision@3: 0.6585
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7926, Precision@3: 0.6587
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7924, Precision@3: 0.6585
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7927, Precision@3: 0.6589
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8546, Precision@3: 0.7079
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8536, Precision@3: 0.7073
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8511, Precision@3: 0.7049
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8513, Precision@3: 0.7047
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8609, Precision@3: 0.7133
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8615, Precision@3: 0.7140
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8611, Precision@3: 0.7135
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8594, Precision@3: 0.7127
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8858, Precision@3: 0.7334
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8877, Precision@3: 0.7353
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8862, Precision@3: 0.7340
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8831, Precision@3: 0.7321
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8855, Precision@3: 0.7338
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8858, Precision@3: 0.7338
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8867, Precision@3: 0.7347
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8878, Precision@3: 0.7360
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7805, Precision@3: 0.6494
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7803, Precision@3: 0.6492
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7804, Precision@3: 0.6496
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7796, Precision@3: 0.6488
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7905, Precision@3: 0.6574
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7904, Precision@3: 0.6572
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7905, Precision@3: 0.6570
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7906, Precision@3: 0.6572
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8635, Precision@3: 0.7151
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8638, Precision@3: 0.7151
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8663, Precision@3: 0.7170
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8631, Precision@3: 0.7150
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8710, Precision@3: 0.7213
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8698, Precision@3: 0.7206
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8711, Precision@3: 0.7219
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8704, Precision@3: 0.7215
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8837, Precision@3: 0.7325
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8806, Precision@3: 0.7304
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8835, Precision@3: 0.7323
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8835, Precision@3: 0.7323
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8865, Precision@3: 0.7349
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8824, Precision@3: 0.7317
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8869, Precision@3: 0.7345
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8842, Precision@3: 0.7334
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7838, Precision@3: 0.6507
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7843, Precision@3: 0.6509
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7837, Precision@3: 0.6505
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7850, Precision@3: 0.6516
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7927, Precision@3: 0.6593
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7940, Precision@3: 0.6604
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7937, Precision@3: 0.6602
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7945, Precision@3: 0.6609
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8707, Precision@3: 0.7219
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8729, Precision@3: 0.7245
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8695, Precision@3: 0.7213
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8697, Precision@3: 0.7211
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8753, Precision@3: 0.7258
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8790, Precision@3: 0.7288
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8780, Precision@3: 0.7271
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8757, Precision@3: 0.7260
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8839, Precision@3: 0.7327
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8824, Precision@3: 0.7310
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8861, Precision@3: 0.7340
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8862, Precision@3: 0.7340
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8870, Precision@3: 0.7349
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8893, Precision@3: 0.7364
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8855, Precision@3: 0.7345
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8846, Precision@3: 0.7334
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7828, Precision@3: 0.6531
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7828, Precision@3: 0.6531
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7828, Precision@3: 0.6531
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7828, Precision@3: 0.6531
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7919, Precision@3: 0.6600
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7915, Precision@3: 0.6600
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7915, Precision@3: 0.6600
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7915, Precision@3: 0.6600
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8376, Precision@3: 0.6954
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8378, Precision@3: 0.6956
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8376, Precision@3: 0.6954
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8378, Precision@3: 0.6956
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8518, Precision@3: 0.7064
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8514, Precision@3: 0.7062
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8508, Precision@3: 0.7058
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8516, Precision@3: 0.7064
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8761, Precision@3: 0.7269
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8761, Precision@3: 0.7269
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8761, Precision@3: 0.7269
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8764, Precision@3: 0.7271
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8745, Precision@3: 0.7269
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8741, Precision@3: 0.7265
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8745, Precision@3: 0.7269
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8741, Precision@3: 0.7265
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7857, Precision@3: 0.6544
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7854, Precision@3: 0.6542
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7857, Precision@3: 0.6544
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7857, Precision@3: 0.6544
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7841, Precision@3: 0.6531
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7838, Precision@3: 0.6531
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7841, Precision@3: 0.6531
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7838, Precision@3: 0.6531
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8544, Precision@3: 0.7079
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8538, Precision@3: 0.7077
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8541, Precision@3: 0.7079
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8541, Precision@3: 0.7079
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8603, Precision@3: 0.7137
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8605, Precision@3: 0.7140
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8603, Precision@3: 0.7137
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8605, Precision@3: 0.7140
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8726, Precision@3: 0.7250
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8731, Precision@3: 0.7254
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8729, Precision@3: 0.7252
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8734, Precision@3: 0.7256
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8779, Precision@3: 0.7295
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8779, Precision@3: 0.7295
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8779, Precision@3: 0.7295
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8779, Precision@3: 0.7295
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7764, Precision@3: 0.6457
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7764, Precision@3: 0.6457
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7764, Precision@3: 0.6457
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7764, Precision@3: 0.6457
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7797, Precision@3: 0.6466
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7797, Precision@3: 0.6466
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7797, Precision@3: 0.6466
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7797, Precision@3: 0.6466
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8603, Precision@3: 0.7137
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8600, Precision@3: 0.7137
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8603, Precision@3: 0.7137
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8600, Precision@3: 0.7137
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8643, Precision@3: 0.7181
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8643, Precision@3: 0.7181
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8646, Precision@3: 0.7183
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8643, Precision@3: 0.7181
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8744, Precision@3: 0.7254
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8737, Precision@3: 0.7250
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8744, Precision@3: 0.7254
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8737, Precision@3: 0.7250
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8731, Precision@3: 0.7260
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8728, Precision@3: 0.7258
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8731, Precision@3: 0.7260
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8728, Precision@3: 0.7258
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7805, Precision@3: 0.6497
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7807, Precision@3: 0.6499
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7805, Precision@3: 0.6497
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7807, Precision@3: 0.6499
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7818, Precision@3: 0.6514
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7818, Precision@3: 0.6514
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7820, Precision@3: 0.6516
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7818, Precision@3: 0.6514
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8171, Precision@3: 0.6749
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8173, Precision@3: 0.6751
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8171, Precision@3: 0.6749
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8173, Precision@3: 0.6751
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8228, Precision@3: 0.6792
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8229, Precision@3: 0.6792
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8224, Precision@3: 0.6790
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8226, Precision@3: 0.6790
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8307, Precision@3: 0.6876
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8309, Precision@3: 0.6876
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8309, Precision@3: 0.6878
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8312, Precision@3: 0.6881
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8276, Precision@3: 0.6846
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8288, Precision@3: 0.6853
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8291, Precision@3: 0.6859
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8288, Precision@3: 0.6857
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7821, Precision@3: 0.6499
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7818, Precision@3: 0.6496
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7822, Precision@3: 0.6499
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7822, Precision@3: 0.6499
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7720, Precision@3: 0.6416
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7720, Precision@3: 0.6416
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7725, Precision@3: 0.6421
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7720, Precision@3: 0.6416
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8159, Precision@3: 0.6743
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8158, Precision@3: 0.6738
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8161, Precision@3: 0.6745
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8157, Precision@3: 0.6740
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8242, Precision@3: 0.6811
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8235, Precision@3: 0.6805
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8236, Precision@3: 0.6809
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8236, Precision@3: 0.6809
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8290, Precision@3: 0.6861
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8309, Precision@3: 0.6872
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8274, Precision@3: 0.6848
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8301, Precision@3: 0.6868
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8253, Precision@3: 0.6820
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8261, Precision@3: 0.6827
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8259, Precision@3: 0.6825
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8262, Precision@3: 0.6829
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7632, Precision@3: 0.6360
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7632, Precision@3: 0.6360
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7630, Precision@3: 0.6358
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7632, Precision@3: 0.6360
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7645, Precision@3: 0.6350
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7645, Precision@3: 0.6350
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7645, Precision@3: 0.6350
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7645, Precision@3: 0.6350
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8198, Precision@3: 0.6775
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8199, Precision@3: 0.6775
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8198, Precision@3: 0.6775
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8197, Precision@3: 0.6773
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8237, Precision@3: 0.6814
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8233, Precision@3: 0.6809
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8233, Precision@3: 0.6809
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8235, Precision@3: 0.6811
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8263, Precision@3: 0.6827
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8267, Precision@3: 0.6831
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8255, Precision@3: 0.6818
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8270, Precision@3: 0.6829
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8210, Precision@3: 0.6781
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8192, Precision@3: 0.6768
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8196, Precision@3: 0.6771
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8209, Precision@3: 0.6781
# Best engineered params: {'loss': 'warp', 'no_components': 64, 'learning_rate': 0.05, 'epochs': 50, 'user_alpha': 1e-05, 'item_alpha': 0.0001, 'top3_accuracy': 0.8893440275197847, 'precision@3': 0.73641646}

# %%
# Evaluate final model using the engineered feature set.
metrics_eng, recommendations_eng = evaluate_lightfm_model(
    X_train_eng_full, X_test_eng, Y_train_bin, Y_test_bin, final_feature_set, best_params_eng, label_cols
)

print("\nFinal Engineered Model Metrics:")
for metric, value in metrics_eng.items():
    print(f"{metric}: {value:.4f}")

print("\nTop 3 product recommendations for sample test users (Engineered Features):")
for uid in list(recommendations_eng.keys())[:5]:
    print(f"User {uid}: {recommendations_eng[uid]}")
# Out:
# Final Engineered Model Metrics:
# precision@3: 0.7187
# custom_top3_accuracy: 0.8798
#
# Top 3 product recommendations for sample test users (Engineered Features):
# User 0: ['Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card', 'Label_Insurance_Solutions']
# User 1: ['Label_Retention_Efforts', 'Label_Rewards_Credit_Card', 'Label_Travel_Rewards_Card']
# User 2: ['Label_Card_Upgrade', 'Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card']
# User 3: ['Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card', 'Label_Commodity_Investment_Services']
# User 4: ['Label_Retention_Efforts', 'Label_Card_Upgrade', 'Label_Travel_Rewards_Card']

# %%
pcapoly = PCA(n_components=63, random_state=42)
X_poly_pca = pcapoly.fit_transform(X_poly_scaled)
pca_feature_names = [f'pca_{i}' for i in range(X_poly_pca.shape[1])]

# Instead of concatenating with the original expanded features, 
# we use only the PCA-transformed polynomial features as the final engineered features.
df_engineered = pd.DataFrame(X_poly_pca, columns=pca_feature_names, index=df_imputed_original.index)
final_feature_set = pca_feature_names

# -----------------------------------------------------------
# Step 5: Split the engineered data and binarized labels into train and test sets.
X_train_eng_full, X_test_eng, Y_train_bin, Y_test_bin = train_test_split(
    df_engineered, Y_bin, test_size=0.2, random_state=42
)

print("\n--- Running grid search for engineered features (using only PCA components) ---")
best_params_eng, all_results_eng = grid_search_cv(final_feature_set, X_train_eng_full, Y_train_bin)
print(f"Best engineered params: {best_params_eng}")
# Out:
# --- Running grid search for engineered features (using only PCA components) ---
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8095, Precision@3: 0.6682
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8091, Precision@3: 0.6680
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8091, Precision@3: 0.6680
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8095, Precision@3: 0.6682
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8136, Precision@3: 0.6738
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8139, Precision@3: 0.6740
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8134, Precision@3: 0.6736
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8139, Precision@3: 0.6740
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8688, Precision@3: 0.7202
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8682, Precision@3: 0.7194
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8683, Precision@3: 0.7191
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8693, Precision@3: 0.7207
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8736, Precision@3: 0.7247
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8747, Precision@3: 0.7250
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8740, Precision@3: 0.7245
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8741, Precision@3: 0.7245
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8816, Precision@3: 0.7310
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8829, Precision@3: 0.7312
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8808, Precision@3: 0.7302
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8799, Precision@3: 0.7291
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8832, Precision@3: 0.7334
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8831, Precision@3: 0.7314
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8819, Precision@3: 0.7310
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8822, Precision@3: 0.7308
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7968, Precision@3: 0.6604
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7966, Precision@3: 0.6600
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7967, Precision@3: 0.6600
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7969, Precision@3: 0.6604
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8053, Precision@3: 0.6680
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8047, Precision@3: 0.6675
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8047, Precision@3: 0.6673
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8060, Precision@3: 0.6684
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8747, Precision@3: 0.7247
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8773, Precision@3: 0.7278
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8776, Precision@3: 0.7275
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8762, Precision@3: 0.7263
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8805, Precision@3: 0.7297
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8791, Precision@3: 0.7286
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8791, Precision@3: 0.7288
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8793, Precision@3: 0.7284
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8827, Precision@3: 0.7314
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8814, Precision@3: 0.7308
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8800, Precision@3: 0.7297
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8850, Precision@3: 0.7334
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8801, Precision@3: 0.7299
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8811, Precision@3: 0.7304
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8861, Precision@3: 0.7338
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8845, Precision@3: 0.7330
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7902, Precision@3: 0.6567
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7906, Precision@3: 0.6569
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7911, Precision@3: 0.6569
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7918, Precision@3: 0.6578
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8017, Precision@3: 0.6660
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8026, Precision@3: 0.6667
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8025, Precision@3: 0.6667
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8022, Precision@3: 0.6664
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8752, Precision@3: 0.7258
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8780, Precision@3: 0.7282
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8776, Precision@3: 0.7273
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8751, Precision@3: 0.7252
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8791, Precision@3: 0.7293
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8798, Precision@3: 0.7304
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8811, Precision@3: 0.7306
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8777, Precision@3: 0.7273
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8821, Precision@3: 0.7303
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8831, Precision@3: 0.7304
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8837, Precision@3: 0.7321
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8783, Precision@3: 0.7276
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8820, Precision@3: 0.7310
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8828, Precision@3: 0.7306
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8820, Precision@3: 0.7323
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8832, Precision@3: 0.7317
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7985, Precision@3: 0.6623
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7985, Precision@3: 0.6623
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7985, Precision@3: 0.6623
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7985, Precision@3: 0.6623
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8036, Precision@3: 0.6676
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8038, Precision@3: 0.6678
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8038, Precision@3: 0.6678
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8038, Precision@3: 0.6678
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8485, Precision@3: 0.7040
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8481, Precision@3: 0.7038
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8489, Precision@3: 0.7045
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8487, Precision@3: 0.7043
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8590, Precision@3: 0.7127
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8585, Precision@3: 0.7122
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8590, Precision@3: 0.7127
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8590, Precision@3: 0.7124
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8718, Precision@3: 0.7237
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8714, Precision@3: 0.7235
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8718, Precision@3: 0.7237
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8714, Precision@3: 0.7235
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8743, Precision@3: 0.7256
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8748, Precision@3: 0.7260
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8748, Precision@3: 0.7260
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8746, Precision@3: 0.7258
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7879, Precision@3: 0.6554
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7879, Precision@3: 0.6554
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7879, Precision@3: 0.6554
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7879, Precision@3: 0.6554
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7889, Precision@3: 0.6576
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7889, Precision@3: 0.6576
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7889, Precision@3: 0.6576
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7889, Precision@3: 0.6576
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8552, Precision@3: 0.7098
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8555, Precision@3: 0.7101
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8555, Precision@3: 0.7101
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8555, Precision@3: 0.7101
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8607, Precision@3: 0.7139
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8607, Precision@3: 0.7139
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8612, Precision@3: 0.7144
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8612, Precision@3: 0.7144
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8745, Precision@3: 0.7256
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8739, Precision@3: 0.7252
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8742, Precision@3: 0.7254
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8737, Precision@3: 0.7250
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8745, Precision@3: 0.7260
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8748, Precision@3: 0.7262
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8745, Precision@3: 0.7260
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8744, Precision@3: 0.7260
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7801, Precision@3: 0.6483
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7801, Precision@3: 0.6483
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7801, Precision@3: 0.6483
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7801, Precision@3: 0.6483
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7826, Precision@3: 0.6505
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7826, Precision@3: 0.6505
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7826, Precision@3: 0.6505
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7826, Precision@3: 0.6505
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8554, Precision@3: 0.7103
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8552, Precision@3: 0.7101
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8552, Precision@3: 0.7101
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8552, Precision@3: 0.7101
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8597, Precision@3: 0.7137
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8593, Precision@3: 0.7135
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8597, Precision@3: 0.7137
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8597, Precision@3: 0.7137
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8722, Precision@3: 0.7241
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8722, Precision@3: 0.7241
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8724, Precision@3: 0.7243
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8721, Precision@3: 0.7243
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8728, Precision@3: 0.7239
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8722, Precision@3: 0.7232
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8726, Precision@3: 0.7236
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8719, Precision@3: 0.7230
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7797, Precision@3: 0.6505
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7797, Precision@3: 0.6505
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7797, Precision@3: 0.6505
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7797, Precision@3: 0.6505
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7838, Precision@3: 0.6537
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7835, Precision@3: 0.6535
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7838, Precision@3: 0.6537
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7838, Precision@3: 0.6537
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8169, Precision@3: 0.6730
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8171, Precision@3: 0.6732
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8169, Precision@3: 0.6730
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8171, Precision@3: 0.6732
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8166, Precision@3: 0.6725
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8164, Precision@3: 0.6723
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8164, Precision@3: 0.6723
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8162, Precision@3: 0.6721
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8153, Precision@3: 0.6699
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8147, Precision@3: 0.6697
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8163, Precision@3: 0.6710
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8167, Precision@3: 0.6715
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8087, Precision@3: 0.6637
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8099, Precision@3: 0.6641
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8085, Precision@3: 0.6632
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8090, Precision@3: 0.6632
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7865, Precision@3: 0.6535
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7865, Precision@3: 0.6535
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7865, Precision@3: 0.6535
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7865, Precision@3: 0.6535
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7750, Precision@3: 0.6433
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7750, Precision@3: 0.6433
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7750, Precision@3: 0.6433
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7750, Precision@3: 0.6433
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8136, Precision@3: 0.6680
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8136, Precision@3: 0.6680
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8141, Precision@3: 0.6682
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8139, Precision@3: 0.6680
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8169, Precision@3: 0.6699
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8165, Precision@3: 0.6695
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8164, Precision@3: 0.6693
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8163, Precision@3: 0.6693
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8083, Precision@3: 0.6626
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8095, Precision@3: 0.6635
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8085, Precision@3: 0.6628
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8106, Precision@3: 0.6643
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7997, Precision@3: 0.6546
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8017, Precision@3: 0.6563
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8015, Precision@3: 0.6559
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8022, Precision@3: 0.6565
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7640, Precision@3: 0.6345
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7638, Precision@3: 0.6343
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7642, Precision@3: 0.6347
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7640, Precision@3: 0.6345
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7612, Precision@3: 0.6293
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7610, Precision@3: 0.6291
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7612, Precision@3: 0.6293
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7610, Precision@3: 0.6291
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8069, Precision@3: 0.6622
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8074, Precision@3: 0.6626
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8071, Precision@3: 0.6624
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8065, Precision@3: 0.6617
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8027, Precision@3: 0.6576
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8025, Precision@3: 0.6574
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8028, Precision@3: 0.6576
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8028, Precision@3: 0.6576
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8017, Precision@3: 0.6544
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8010, Precision@3: 0.6546
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8015, Precision@3: 0.6546
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8023, Precision@3: 0.6555
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7951, Precision@3: 0.6494
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7953, Precision@3: 0.6499
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7972, Precision@3: 0.6511
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7960, Precision@3: 0.6503
# Best engineered params: {'loss': 'warp', 'no_components': 32, 'learning_rate': 0.05, 'epochs': 50, 'user_alpha': 0.0001, 'item_alpha': 1e-05, 'top3_accuracy': 0.8860873285438103, 'precision@3': 0.7338029}

# %%
# Evaluate final model using the engineered feature set.
metrics_eng, recommendations_eng = evaluate_lightfm_model(
    X_train_eng_full, X_test_eng, Y_train_bin, Y_test_bin, final_feature_set, best_params_eng, label_cols
)

print("\nFinal Engineered Model Metrics:")
for metric, value in metrics_eng.items():
    print(f"{metric}: {value:.4f}")

print("\nTop 3 product recommendations for sample test users (Engineered Features):")
for uid in list(recommendations_eng.keys())[:5]:
    print(f"User {uid}: {recommendations_eng[uid]}")
# Out:
# Final Engineered Model Metrics:
# precision@3: 0.7238
# custom_top3_accuracy: 0.8853
#
# Top 3 product recommendations for sample test users (Engineered Features):
# User 0: ['Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card', 'Label_Retention_Efforts']
# User 1: ['Label_Retention_Efforts', 'Label_Insurance_Solutions', 'Label_Rewards_Credit_Card']
# User 2: ['Label_Card_Upgrade', 'Label_Travel_Rewards_Card', 'Label_Insurance_Solutions']
# User 3: ['Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card', 'Label_Card_Upgrade']
# User 4: ['Label_Retention_Efforts', 'Label_Travel_Rewards_Card', 'Label_Card_Upgrade']

# %% [markdown]
# ## Conclusion:
# Using polynomial features has proven to yield significantly improved results in our modeling efforts by uncovering complex, nonlinear interactions that are otherwise hidden in the original data. After applying PCA to distill the most important and uncorrelated components from our dataset, we generate polynomial features on these components to effectively capture higher-order relationships among them. This approach allows us to model intricate dependencies without suffering from the curse of dimensionality that would occur if polynomial expansion were applied to the original, high-dimensional data. Empirical evidence from our experiments shows that models incorporating these polynomial features consistently outperform those using only linear combinations of the principal components, indicating that the nonlinear interactions captured are indeed critical to the underlying data structure. In conclusion, the use of polynomial features, built upon a PCA-transformed dataset, not only enhances predictive accuracy but also provides a more nuanced understanding of the complex relationships driving the behavior of our data.
