# %%
import pandas as pd
import numpy as np
import json
from scipy.sparse import csr_matrix, identity
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from lightfm import LightFM
from lightfm.evaluation import precision_at_k, auc_score
from sklearn.metrics import accuracy_score, f1_score
import itertools
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA

# %% [markdown]
# ### Load data

# %%
df_imputed_original = pd.read_csv('../data/processed/imputed_data.csv')

# %% [markdown]
# ### Label Construction
# To train the recommendation system, we need to construct labels that indicating whether a person has purchased certain financial products, which can be derived from the characteristics of demographic data and categorical spending data.
# Joint features are used for label construction, while purchase behavior (e.g., spending in categories like restaurants, utilities, or digital goods) gives insight into interests and lifestyle, it doesn't tell the full story about a customer's financial capacity, needs, or creditworthiness — all of which are critical for financial product targeting.
#
# Median and quantiles for certain features are computed for threshold-based rules.

# %%
income_median = df_imputed_original['yearly_income'].median()
num_cards_median = df_imputed_original['num_credit_cards'].median()
credit_upper = df_imputed_original['credit_score'].quantile(0.75)
credit_limit_upper = df_imputed_original['Credit_limit'].quantile(0.75)
debit_lower = df_imputed_original['Debit_limit'].quantile(0.25)
income_80 = df_imputed_original['yearly_income'].quantile(0.80)  

# For each spending category used in the rules, compute its 75th percentile.
spending_categories = [
    'Retail Stores', 'Restaurants & Eating Places', 'Clothing & Fashion', 
    'Movies & Theaters', 'Sports & Recreational Activities', 'Freight & Trucking', 
    'Medical & Healthcare Services', 'Postal Services - Government Only', 
    'Digital Goods & Computers', 'Telecommunications & Media', 'Utilities & Home Services', 
    'Automotive & Transportation Services', 'Steel & Metal Products', 'Machinery & Tools', 
    'Rail & Bus Transport', 'Hotels & Accommodation', 'Legal & Financial Services'
]
spending_upper = {cat: df_imputed_original[cat].quantile(0.75) for cat in spending_categories}

# %% [markdown]
# ### Rules for label construction

# %%
# 1. Rewards Credit Card:
#    Conditions: (a) any spending category (Retail, Restaurants, Fashion, Movies, Sports) above its upper quantile,
#                (b) credit score above upper quantile,
#                (c) number of credit cards above or equal to median.
def label_rewards_credit_card(row):
    score = 0
    cats = ['Retail Stores', 'Restaurants & Eating Places', 'Clothing & Fashion', 
            'Movies & Theaters', 'Sports & Recreational Activities']
    if any(row[cat] >= spending_upper[cat] for cat in cats):
        score += 1
    if row['credit_score'] >= credit_upper:
        score += 1
    if row['num_credit_cards'] >= num_cards_median:
        score += 1
    return min(score, 3)

# 2. Insurance Solutions:
#    Conditions: (a) any spending category (Freight, Healthcare, Government Postal) above its upper quantile,
#                (b) credit score between median and 80th percentile,
#                (c) yearly income above or equal to median.
def label_insurance_solutions(row):
    score = 0
    cats = ['Freight & Trucking', 'Medical & Healthcare Services', 'Postal Services - Government Only']
    if any(row[cat] >= spending_upper[cat] for cat in cats):
        score += 1
    credit_median = df_imputed_original['credit_score'].quantile(0.50)
    credit_80 = df_imputed_original['credit_score'].quantile(0.80)
    if credit_median < row['credit_score'] <= credit_80:
        score += 1
    if row['yearly_income'] >= income_median:
        score += 1
    return min(score, 3)

# 3. Digital Financing:
#    Conditions: (a) any spending category above its upper quantile,
#                (b) yearly income above median,
#                (c) credit score above upper quantile.
def label_digital_financing(row):
    score = 0
    cats = ['Digital Goods & Computers', 'Telecommunications & Media']
    if any(row[cat] >= spending_upper[cat] for cat in cats):
        score += 1
    if row['yearly_income'] >= income_median:
        score += 1
    if row['credit_score'] >= credit_upper:
        score += 1
    return min(score, 3)

# 4. Home Improvement Loan (loan-related):
#    Conditions: Credit score must exceed upper quantile (else 0),
#                (a) spending in Utilities & Home Services above its upper quantile,
#                (b) yearly income above median.
def label_home_improvement_loan(row):
    score = 0 
    if row['credit_score'] >= credit_upper:
        score += 1
    if row['Utilities & Home Services'] >= spending_upper['Utilities & Home Services']:
        score += 1
    if row['yearly_income'] >= income_median:
        score += 1
    return min(score, 3)

# 5. Auto & Vehicle Financing (loan-related):
#    Conditions: Credit score must exceed upper quantile,
#                (a) spending in Automotive & Transportation Services above its upper quantile,
#                (b) yearly income above median.
def label_auto_vehicle_financing(row):
    score = 0 # Base point for meeting credit requirement
    if row['credit_score'] >= credit_upper:
        score += 1
    if row['Automotive & Transportation Services'] >= spending_upper['Automotive & Transportation Services']:
        score += 1
    if row['yearly_income'] >= income_median:
        score += 1
    return min(score, 3)

# 6. Commodity & Investment Services:
#    Conditions: (a) any spending category (Steel & Metal Products or Machinery & Tools) above its upper quantile,
#                (b) yearly income above median,
#                (c) low total debt relative to income (total_debt < 0.5*yearly_income).
def label_commodity_investment_services(row):
    score = 0
    cats = ['Steel & Metal Products', 'Machinery & Tools']
    if any(row[cat] >= spending_upper[cat] for cat in cats):
        score += 1
    if row['yearly_income'] >= income_80:
        score += 1
    if row['total_debt'] <= 0.5 * row['yearly_income']:
        score += 1
    return min(score, 3)

# 7. Travel Rewards Card:
#    Conditions: (a) any spending category (Rail & Bus Transport or Hotels & Accommodation) above its upper quantile,
#                (b) yearly income above median,
#                (c) number of credit cards above median.
def label_travel_rewards_card(row):
    score = 0
    cats = ['Rail & Bus Transport', 'Hotels & Accommodation']
    if any(row[cat] >= spending_upper[cat] for cat in cats):
        score += 1
    if row['yearly_income'] >= income_median:
        score += 1
    if row['num_credit_cards'] >= num_cards_median:
        score += 1
    return min(score, 3)

# 8. Savings/Investment Plans:
#    Conditions remain unchanged.
def label_savings_investment_plans(row):
    score = 0
    if row['Debit_limit'] >= 1.5 * row['Credit_limit']:
        score += 1
    if row['total_debt'] < 0.5 * row['yearly_income']:
        score += 1
    if row['retirement_age'] - row['current_age'] <= 15:
        score += 1
    return min(score, 3)

# 9. Wealth Management & Savings:
#    Conditions: (a) spending in Legal & Financial Services above its upper quantile,
#                (b) yearly income above median and low total debt,
#                (c) credit score above upper quantile.
def label_wealth_management_savings(row):
    score = 0
    if row['Legal & Financial Services'] >= spending_upper['Legal & Financial Services']:
        score += 1
    if row['yearly_income'] >= income_80 and row['total_debt'] < 0.5 * row['yearly_income']:
        score += 1
    if row['credit_score'] >= credit_upper:
        score += 1
    return min(score, 3)

# 10. Label Card Upgrade:
#    Conditions:
#      (a) if has_chip is 0, give 1 credit,
#      (b) if Credit_expires is after 2022, give 1 credit,
#      (c) if Credit_limit > credit_limit_upper, give 1 credit.
def label_card_upgrade(row):
    score = 0
    if row['has_chip'] == 0:
        score += 1
    if (row['Credit_expires'] > 2021 or 
        row['Debit_expires'] > 2021 or 
        row['Debit (Prepaid)_expires'] > 2021):
        score += 1
    if row['Credit_limit'] > credit_limit_upper:
        score += 1
    return min(score, 3)

# 11. Label Retention Efforts:
#    Conditions:
#      (a) if any of Credit_expires, Debit_expires, or Debit (Prepaid)_expires is greater than 2021, give 1 credit,
#      (b) if num_cards_issued is less than or equal to 2, give 1 credit,
#      (c) if Debit_limit is less than debit_lower, give 1 credit.
def label_retention_efforts(row):
    score = 0
    if (row['Credit_expires'] > 2021 or 
        row['Debit_expires'] > 2021 or 
        row['Debit (Prepaid)_expires'] > 2021):
        score += 1
    if row['num_credit_cards'] <= 2:
        score += 1
    if row['Debit_limit'] < debit_lower:
        score += 1
    return min(score, 3)

# %% [markdown]
# ### Computed labels for each financial product

# %%
# Apply label functions to construct new label columns.
df_imputed_original['Label_Rewards_Credit_Card'] = df_imputed_original.apply(label_rewards_credit_card, axis=1)
df_imputed_original['Label_Insurance_Solutions'] = df_imputed_original.apply(label_insurance_solutions, axis=1)
df_imputed_original['Label_Digital_Financing'] = df_imputed_original.apply(label_digital_financing, axis=1)
df_imputed_original['Label_Home_Improvement_Loan'] = df_imputed_original.apply(label_home_improvement_loan, axis=1)
df_imputed_original['Label_Auto_Vehicle_Financing'] = df_imputed_original.apply(label_auto_vehicle_financing, axis=1)
df_imputed_original['Label_Commodity_Investment_Services'] = df_imputed_original.apply(label_commodity_investment_services, axis=1)
df_imputed_original['Label_Travel_Rewards_Card'] = df_imputed_original.apply(label_travel_rewards_card, axis=1)
df_imputed_original['Label_Savings_Investment_Plans'] = df_imputed_original.apply(label_savings_investment_plans, axis=1)
df_imputed_original['Label_Wealth_Management_Savings'] = df_imputed_original.apply(label_wealth_management_savings, axis=1)
df_imputed_original['Label_Card_Upgrade'] = df_imputed_original.apply(label_card_upgrade, axis=1)
df_imputed_original['Label_Retention_Efforts'] = df_imputed_original.apply(label_retention_efforts, axis=1)


print("Sample label counts:")
df_imputed_original[['Label_Rewards_Credit_Card', 'Label_Insurance_Solutions',
                           'Label_Digital_Financing', 'Label_Home_Improvement_Loan',
                           'Label_Auto_Vehicle_Financing', 'Label_Commodity_Investment_Services',
                           'Label_Travel_Rewards_Card', 'Label_Savings_Investment_Plans',
                           'Label_Wealth_Management_Savings','Label_Card_Upgrade','Label_Retention_Efforts']].head()
# Out:
# Sample label counts:
#    Label_Rewards_Credit_Card  Label_Insurance_Solutions  \
# 0                          3                          3
# 1                          2                          1
# 2                          1                          1
# 3                          2                          0
# 4                          2                          2
#
#    Label_Digital_Financing  Label_Home_Improvement_Loan  \
# 0                        3                            3
# 1                        1                            1
# 2                        0                            0
# 3                        1                            0
# 4                        2                            1
#
#    Label_Auto_Vehicle_Financing  Label_Commodity_Investment_Services  \
# 0                             3                                    2
# 1                             1                                    1
# 2                             0                                    0
# 3                             0                                    0
# 4                             1                                    1
#
#    Label_Travel_Rewards_Card  Label_Savings_Investment_Plans  \
# 0                          3                               1
# 1                          3                               1
# 2                          1                               1
# 3                          1                               1
# 4                          2                               1
#
#    Label_Wealth_Management_Savings  Label_Card_Upgrade  \
# 0                                1                   1
# 1                                0                   2
# 2                                1                   2
# 3                                0                   2
# 4                                1                   2
#
#    Label_Retention_Efforts
# 0                        0
# 1                        0
# 2                        1
# 3                        1
# 4                        1

# %% [markdown]
# ### Save imputed data with label

# %%
df_imputed_original.to_csv('../data/processed/imputed_data_with_label.csv', index=False)

# %% [markdown]
# Computes the top-3 accuracy for a recommender system model.
# This metric evaluates how often the true purchased items for each user appear in the model's top-3 predicted recommendations.
# Users with no recorded purchases are excluded from accuracy computation.
#
# Business Rationale:
# -------------------
# - Reflects realistic scenarios: In real-world recommendation systems, users interact with only a small subset of items.
# - Focuses on meaningful users: Only evaluates users who made actual purchases — avoids inflating performance with inactive users.
# - Top-3 is practical: Many businesses (e.g., e-commerce, fintech) care about whether their top few suggestions convert.
# - Scalable scoring: Gives partial credit (e.g., 0.5) when only some of the true purchases are recommended, reflecting degrees of success.

# %%
def compute_top3_accuracy_for_fold(model, X_val, interactions_val, item_features, k=3):
    num_users = X_val.shape[0]
    top3_acc = []
    users_with_purchases = 0  # Track users who actually bought something
    
    for user_id in range(num_users):
        # Predict scores for all items for this user
        scores = model.predict(user_id, np.arange(interactions_val.shape[1]),
                             user_features=X_val,
                             item_features=item_features)
        
        # Get top k predicted item indices
        top3_indices = np.argsort(-scores)[:k]
        
        # Get true purchased item indices
        true_positives = set(np.where(interactions_val[user_id].toarray().flatten() == 1)[0])
        n_true = len(true_positives)
        
        # Skip users with no purchases (do not count them in accuracy)
        if n_true == 0:
            continue
        
        users_with_purchases += 1
        
        # Case 1: User purchased 3+ items
        if n_true >= 3:
            count = len(set(top3_indices).intersection(true_positives))
            top3_acc.append(count / 3.0)
        
        # Case 2: User purchased exactly 2 items
        elif n_true == 2:
            intersection = set(top3_indices).intersection(true_positives)
            if len(intersection) == 2:
                top3_acc.append(1.0)
            elif len(intersection) == 1:
                top3_acc.append(0.5)
            else:
                top3_acc.append(0)
        
        # Case 3: User purchased exactly 1 item
        elif n_true == 1:
            if top3_indices[0] in true_positives:
                top3_acc.append(1.0)
            elif len(set(top3_indices[1:]).intersection(true_positives)) > 0:
                top3_acc.append(0.5)
            else:
                top3_acc.append(0)
    
    # Return 0 if no users made purchases (edge case)
    if users_with_purchases == 0:
        return 0.0
    
    return np.mean(top3_acc)

# %% [markdown]
# ### Define grid search function for `lightfm`, as it cannot run `GridSearchCV` function directly.
#
# The `grid_search_cv` function performs a comprehensive grid search to optimize hyperparameters for a LightFM recommendation model using 5-fold cross-validation. It first extracts and standardizes user features based on a provided feature list, converting them into a sparse matrix, and then constructs an interaction matrix and an identity-based item features matrix. For each combination of hyperparameters (including loss function, number of components, learning rate, epochs, and regularization parameters), the function splits the training data into folds, applies upsampling on minority classes for each product column in the training interactions, and trains a LightFM model on the imputed data. It then evaluates the model on the validation set using both a standard precision@3 metric and a custom top-3 accuracy function, averaging the scores over the folds. All results are recorded and printed, and the function returns the best hyperparameters based on the highest average top-3 accuracy.

# %%
def grid_search_cv(feature_list, X_train_full, Y_train_bin):
    # Extract the features from X_train_full based on the provided feature list.
    X_train_features = X_train_full[feature_list].copy()
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_features)
    user_features = csr_matrix(X_train_scaled)
    
    # Build the interaction matrix from Y_train_bin.
    interactions = csr_matrix(Y_train_bin.values)
    num_items = interactions.shape[1]
    item_features = identity(num_items, format='csr')
    
    # Define hyperparameter grid.
    param_grid = {
        'loss': ['warp', 'bpr','logistic'],
        'no_components': [16, 32, 64],
        'learning_rate': [0.001, 0.01, 0.05],
        'epochs': [30, 50],
        'user_alpha': [1e-5, 1e-4],
        'item_alpha': [1e-5, 1e-4]
    }
    
    # Set up 5-fold CV.
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    grid_results = []
    upsample_factor = 2

    for loss, no_components, learning_rate, epochs, user_alpha, item_alpha in itertools.product(
        param_grid['loss'],
        param_grid['no_components'],
        param_grid['learning_rate'],
        param_grid['epochs'],
        param_grid['user_alpha'],
        param_grid['item_alpha']
    ):
        fold_top3_acc = []
        fold_prec = []

        for train_idx, val_idx in kf.split(user_features):
            X_train_cv = user_features[train_idx]
            X_val_cv = user_features[val_idx]
            
            # Get the training interactions for this fold.
            fold_train = interactions[train_idx].toarray().astype(float)
            
            # Upsample the minority class for each product column in the training fold.
            for j in range(fold_train.shape[1]):
                pos_count = np.sum(fold_train[:, j] == 1)
                neg_count = np.sum(fold_train[:, j] == 0)
                if pos_count / fold_train.shape[0] < 0.3:
                    fold_train[:, j] = np.where(fold_train[:, j] == 1,
                                                fold_train[:, j] * upsample_factor,
                                                fold_train[:, j])
                elif neg_count / fold_train.shape[0] < 0.3:
                    fold_train[:, j] = np.where(fold_train[:, j] == 0,
                                                fold_train[:, j] * upsample_factor,
                                                fold_train[:, j])
            fold_train_sparse = csr_matrix(fold_train)
            
            # Validation interactions (untouched).
            fold_val = interactions[val_idx].toarray()
            fold_val_sparse = csr_matrix(fold_val)
            
            # Train LightFM on this fold.
            model_cv = LightFM(loss=loss, no_components=no_components,
                               learning_rate=learning_rate,
                               user_alpha=user_alpha,
                               item_alpha=item_alpha,
                               random_state=42)
            model_cv.fit(fold_train_sparse,
                         user_features=X_train_cv,
                         item_features=item_features,
                         epochs=epochs,
                         num_threads=4)
            
            # Standard precision@3.
            prec = precision_at_k(model_cv, fold_val_sparse,
                                  user_features=X_val_cv,
                                  item_features=item_features,
                                  k=3).mean()
            # Compute custom top-3 accuracy using our function.
            top3_acc = compute_top3_accuracy_for_fold(model_cv, X_val_cv, fold_val_sparse, item_features, k=3)
            
            fold_top3_acc.append(top3_acc)
            fold_prec.append(prec)
        
        avg_top3_acc = np.mean(fold_top3_acc)
        avg_prec = np.mean(fold_prec)
        
        grid_results.append({
            'loss': loss,
            'no_components': no_components,
            'learning_rate': learning_rate,
            'epochs': epochs,
            'user_alpha': user_alpha,
            'item_alpha': item_alpha,
            'top3_accuracy': avg_top3_acc,
            'precision@3': avg_prec
        })
        
        print(f"Params: loss={loss}, components={no_components}, "
              f"lr={learning_rate}, epochs={epochs}, user_alpha={user_alpha}, item_alpha={item_alpha} -> "
              f"Top3 Accuracy: {avg_top3_acc:.4f}, Precision@3: {avg_prec:.4f}")
    
    best_params = max(grid_results, key=lambda x: x['top3_accuracy'])
    return best_params, grid_results

# %% [markdown]
# ### Binarize the ordinal labels: define a "positive" interaction if label >= 2.
#
# ### Feature and Data Splitting Explanation
#
# In the subsequent code snippet, we define three sets of columns: `target_cols` for various spending categories, `feature_cols` for customer and financial attributes used in imputation, and `label_cols` representing the labels for different financial product recommendations. The target variable `Y` is created from the imputed original dataset using the label columns, then binarized by converting values greater than or equal to 2 into 1s, indicating suitability for a particular product. Two user feature sets are prepared: a 'base' set (only using fundamental features) and an 'expanded' set (which includes additional spending categories). These feature sets are stored in a dictionary, and the full dataset is then split into training and testing subsets using a standard 80/20 split, ensuring that the test set remains unmodified for subsequent evaluation of the recommendation model.

# %%
# List of target columns of imputation
target_cols = ['Automotive & Transportation Services', 'Clothing & Fashion',
        'Digital Goods & Computers', 'Electronics & Appliances',
        'Freight & Trucking', 'Hotels & Accommodation',
        'Legal & Financial Services', 'Machinery & Tools',
        'Medical & Healthcare Services', 'Movies & Theaters',
        'Postal Services - Government Only', 'Rail & Bus Transport',
        'Restaurants & Eating Places', 'Retail Stores',
        'Sports & Recreational Activities', 'Steel & Metal Products',
        'Telecommunications & Media', 'Utilities & Home Services']
# List of feature columns used for imputation
feature_cols = ["current_age", "retirement_age", "birth_month", "gender", "yearly_income", "total_debt",
    "credit_score", "Credit_limit", "Debit_limit", "Debit (Prepaid)_limit", "Credit_expires", "Debit_expires",
    "Debit (Prepaid)_expires", "has_chip", "num_credit_cards"]

label_cols = ['Label_Rewards_Credit_Card', 'Label_Insurance_Solutions',
                           'Label_Digital_Financing', 'Label_Home_Improvement_Loan',
                           'Label_Auto_Vehicle_Financing', 'Label_Commodity_Investment_Services',
                           'Label_Travel_Rewards_Card', 'Label_Savings_Investment_Plans',
                           'Label_Wealth_Management_Savings','Label_Card_Upgrade','Label_Retention_Efforts']
Y = df_imputed_original[label_cols].copy()
Y_bin = (Y >= 2).astype(int)

# Prepare user features for tuning.
# Define two feature sets:
base_features = feature_cols.copy()
expanded_features = feature_cols + target_cols  # expanded: include spending categories

# We'll try both feature sets.
feature_sets = {
    'base': base_features,
    'expanded': expanded_features
}

# Split the data into train and test (test set remains unmodified).
X = df_imputed_original.copy()  # full data
X_train_full, X_test, Y_train_bin, Y_test_bin = train_test_split(X, Y_bin, test_size=0.2, random_state=42)

# %% [markdown]
# ### Run both base features and expanded features in hyper-parameter tuning, find best params

# %%
print("\n--- Running grid search for feature set: base ---")
best_params_base, all_results_base = grid_search_cv(base_features, X_train_full, Y_train_bin)
print(f"Best params for base features: {best_params_base}")
print("\n--- Running grid search for feature set: expanded ---")
best_params_expand, all_results_expand = grid_search_cv(expanded_features, X_train_full, Y_train_bin)
print(f"Best params for expanded features: {best_params_expand}")
# Out:
# --- Running grid search for feature set: base ---
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7684, Precision@3: 0.6395
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7682, Precision@3: 0.6392
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7687, Precision@3: 0.6397
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7690, Precision@3: 0.6399
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7745, Precision@3: 0.6436
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7747, Precision@3: 0.6438
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7747, Precision@3: 0.6438
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7747, Precision@3: 0.6438
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8462, Precision@3: 0.6997
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8455, Precision@3: 0.6995
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8469, Precision@3: 0.7004
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8464, Precision@3: 0.7001
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8468, Precision@3: 0.7008
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8466, Precision@3: 0.7010
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8468, Precision@3: 0.7008
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8471, Precision@3: 0.7014
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8517, Precision@3: 0.7068
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8512, Precision@3: 0.7071
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8514, Precision@3: 0.7047
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8511, Precision@3: 0.7051
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8512, Precision@3: 0.7062
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8507, Precision@3: 0.7058
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8516, Precision@3: 0.7064
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8533, Precision@3: 0.7069
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7601, Precision@3: 0.6330
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7599, Precision@3: 0.6328
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7600, Precision@3: 0.6330
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7602, Precision@3: 0.6330
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7766, Precision@3: 0.6451
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7766, Precision@3: 0.6451
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7766, Precision@3: 0.6451
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7774, Precision@3: 0.6457
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8478, Precision@3: 0.7010
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8498, Precision@3: 0.7021
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8473, Precision@3: 0.7001
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8485, Precision@3: 0.7014
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8503, Precision@3: 0.7038
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8500, Precision@3: 0.7034
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8492, Precision@3: 0.7029
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8497, Precision@3: 0.7034
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8488, Precision@3: 0.7036
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8522, Precision@3: 0.7055
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8512, Precision@3: 0.7045
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8537, Precision@3: 0.7062
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8499, Precision@3: 0.7045
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8503, Precision@3: 0.7055
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8493, Precision@3: 0.7042
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8519, Precision@3: 0.7060
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7663, Precision@3: 0.6388
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7657, Precision@3: 0.6375
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7659, Precision@3: 0.6381
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7656, Precision@3: 0.6381
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7801, Precision@3: 0.6498
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7795, Precision@3: 0.6492
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7789, Precision@3: 0.6487
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7793, Precision@3: 0.6492
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8496, Precision@3: 0.7029
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8507, Precision@3: 0.7042
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8507, Precision@3: 0.7036
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8496, Precision@3: 0.7029
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8499, Precision@3: 0.7036
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8512, Precision@3: 0.7045
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8527, Precision@3: 0.7060
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8494, Precision@3: 0.7038
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8466, Precision@3: 0.7030
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8527, Precision@3: 0.7058
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8508, Precision@3: 0.7066
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8474, Precision@3: 0.7021
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8493, Precision@3: 0.7043
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8464, Precision@3: 0.7019
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8519, Precision@3: 0.7068
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8490, Precision@3: 0.7043
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7592, Precision@3: 0.6336
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7592, Precision@3: 0.6336
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7592, Precision@3: 0.6336
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7592, Precision@3: 0.6336
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7703, Precision@3: 0.6407
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7703, Precision@3: 0.6407
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7703, Precision@3: 0.6407
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7703, Precision@3: 0.6407
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8209, Precision@3: 0.6807
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8204, Precision@3: 0.6803
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8204, Precision@3: 0.6803
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8204, Precision@3: 0.6803
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8250, Precision@3: 0.6848
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8248, Precision@3: 0.6846
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8248, Precision@3: 0.6846
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8248, Precision@3: 0.6846
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8370, Precision@3: 0.6943
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8365, Precision@3: 0.6939
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8370, Precision@3: 0.6943
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8365, Precision@3: 0.6939
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8369, Precision@3: 0.6945
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8365, Precision@3: 0.6941
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8369, Precision@3: 0.6945
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8367, Precision@3: 0.6943
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7570, Precision@3: 0.6295
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7570, Precision@3: 0.6295
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7570, Precision@3: 0.6295
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7570, Precision@3: 0.6295
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7712, Precision@3: 0.6401
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7710, Precision@3: 0.6399
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7712, Precision@3: 0.6401
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7710, Precision@3: 0.6399
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8196, Precision@3: 0.6803
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8199, Precision@3: 0.6805
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8196, Precision@3: 0.6803
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8199, Precision@3: 0.6805
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8252, Precision@3: 0.6844
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8252, Precision@3: 0.6844
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8252, Precision@3: 0.6844
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8252, Precision@3: 0.6844
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8377, Precision@3: 0.6946
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8374, Precision@3: 0.6943
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8377, Precision@3: 0.6946
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8374, Precision@3: 0.6943
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8391, Precision@3: 0.6956
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8382, Precision@3: 0.6952
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8393, Precision@3: 0.6958
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8382, Precision@3: 0.6952
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7602, Precision@3: 0.6332
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7602, Precision@3: 0.6332
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7602, Precision@3: 0.6332
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7602, Precision@3: 0.6332
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7702, Precision@3: 0.6399
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7700, Precision@3: 0.6397
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7702, Precision@3: 0.6399
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7700, Precision@3: 0.6397
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8203, Precision@3: 0.6803
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8202, Precision@3: 0.6803
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8203, Precision@3: 0.6803
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8202, Precision@3: 0.6803
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8247, Precision@3: 0.6839
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8245, Precision@3: 0.6837
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8247, Precision@3: 0.6839
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8245, Precision@3: 0.6837
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8369, Precision@3: 0.6941
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8364, Precision@3: 0.6937
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8371, Precision@3: 0.6943
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8364, Precision@3: 0.6937
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8373, Precision@3: 0.6937
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8377, Precision@3: 0.6943
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8377, Precision@3: 0.6939
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8375, Precision@3: 0.6941
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7581, Precision@3: 0.6313
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7581, Precision@3: 0.6313
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7581, Precision@3: 0.6313
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7581, Precision@3: 0.6313
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7584, Precision@3: 0.6295
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7584, Precision@3: 0.6295
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7584, Precision@3: 0.6295
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7584, Precision@3: 0.6295
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7986, Precision@3: 0.6578
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7988, Precision@3: 0.6581
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7984, Precision@3: 0.6576
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7985, Precision@3: 0.6578
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8063, Precision@3: 0.6641
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8064, Precision@3: 0.6641
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8065, Precision@3: 0.6643
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8062, Precision@3: 0.6641
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8112, Precision@3: 0.6673
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8107, Precision@3: 0.6665
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8117, Precision@3: 0.6678
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8110, Precision@3: 0.6669
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8087, Precision@3: 0.6652
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8070, Precision@3: 0.6634
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8079, Precision@3: 0.6647
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8072, Precision@3: 0.6634
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7541, Precision@3: 0.6242
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7543, Precision@3: 0.6244
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7541, Precision@3: 0.6242
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7545, Precision@3: 0.6246
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7523, Precision@3: 0.6216
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7519, Precision@3: 0.6214
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7523, Precision@3: 0.6216
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7519, Precision@3: 0.6214
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8032, Precision@3: 0.6611
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8026, Precision@3: 0.6607
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8028, Precision@3: 0.6609
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8030, Precision@3: 0.6611
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8107, Precision@3: 0.6667
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8106, Precision@3: 0.6665
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8103, Precision@3: 0.6663
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8104, Precision@3: 0.6663
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8042, Precision@3: 0.6608
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8036, Precision@3: 0.6602
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8030, Precision@3: 0.6606
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8026, Precision@3: 0.6596
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7988, Precision@3: 0.6570
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7995, Precision@3: 0.6570
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8002, Precision@3: 0.6580
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7985, Precision@3: 0.6563
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7436, Precision@3: 0.6153
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7434, Precision@3: 0.6151
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7438, Precision@3: 0.6155
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7436, Precision@3: 0.6153
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7461, Precision@3: 0.6149
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7461, Precision@3: 0.6149
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7458, Precision@3: 0.6147
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7458, Precision@3: 0.6147
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7975, Precision@3: 0.6541
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7954, Precision@3: 0.6526
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7975, Precision@3: 0.6541
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7961, Precision@3: 0.6533
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7978, Precision@3: 0.6542
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7977, Precision@3: 0.6540
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7978, Precision@3: 0.6542
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7973, Precision@3: 0.6535
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7954, Precision@3: 0.6531
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7958, Precision@3: 0.6531
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7953, Precision@3: 0.6537
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7952, Precision@3: 0.6526
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7906, Precision@3: 0.6485
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7907, Precision@3: 0.6483
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7894, Precision@3: 0.6483
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7931, Precision@3: 0.6503
# Best params for base features: {'loss': 'warp', 'no_components': 32, 'learning_rate': 0.05, 'epochs': 30, 'user_alpha': 0.0001, 'item_alpha': 0.0001, 'top3_accuracy': 0.8537241060810381, 'precision@3': 0.70618016}
#
# --- Running grid search for feature set: expanded ---
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7546, Precision@3: 0.6276
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7546, Precision@3: 0.6276
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7546, Precision@3: 0.6276
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7546, Precision@3: 0.6276
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7719, Precision@3: 0.6410
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7716, Precision@3: 0.6408
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7718, Precision@3: 0.6410
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7712, Precision@3: 0.6405
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8691, Precision@3: 0.7204
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8675, Precision@3: 0.7196
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8702, Precision@3: 0.7215
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8700, Precision@3: 0.7215
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8756, Precision@3: 0.7260
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8750, Precision@3: 0.7258
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8782, Precision@3: 0.7284
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8764, Precision@3: 0.7269
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8885, Precision@3: 0.7366
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8877, Precision@3: 0.7360
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8878, Precision@3: 0.7360
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8855, Precision@3: 0.7357
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8891, Precision@3: 0.7373
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8898, Precision@3: 0.7383
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8859, Precision@3: 0.7349
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8890, Precision@3: 0.7373
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7488, Precision@3: 0.6235
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7487, Precision@3: 0.6233
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7487, Precision@3: 0.6233
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7491, Precision@3: 0.6233
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7654, Precision@3: 0.6364
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7654, Precision@3: 0.6366
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7652, Precision@3: 0.6362
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7649, Precision@3: 0.6360
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8776, Precision@3: 0.7280
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8761, Precision@3: 0.7260
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8753, Precision@3: 0.7267
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8770, Precision@3: 0.7276
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8817, Precision@3: 0.7319
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8829, Precision@3: 0.7325
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8817, Precision@3: 0.7310
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8825, Precision@3: 0.7316
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8891, Precision@3: 0.7375
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8896, Precision@3: 0.7385
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8881, Precision@3: 0.7368
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8882, Precision@3: 0.7370
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8891, Precision@3: 0.7373
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8879, Precision@3: 0.7370
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8894, Precision@3: 0.7373
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8874, Precision@3: 0.7364
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7576, Precision@3: 0.6310
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7575, Precision@3: 0.6308
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7566, Precision@3: 0.6302
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7565, Precision@3: 0.6300
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7796, Precision@3: 0.6492
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7792, Precision@3: 0.6485
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7792, Precision@3: 0.6485
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7785, Precision@3: 0.6479
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8807, Precision@3: 0.7301
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8800, Precision@3: 0.7297
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8782, Precision@3: 0.7291
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8778, Precision@3: 0.7284
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8849, Precision@3: 0.7338
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8864, Precision@3: 0.7351
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8854, Precision@3: 0.7344
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8854, Precision@3: 0.7342
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8904, Precision@3: 0.7392
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8875, Precision@3: 0.7368
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8851, Precision@3: 0.7338
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8858, Precision@3: 0.7358
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8874, Precision@3: 0.7360
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8854, Precision@3: 0.7347
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8894, Precision@3: 0.7372
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8912, Precision@3: 0.7392
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7546, Precision@3: 0.6287
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7546, Precision@3: 0.6287
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7546, Precision@3: 0.6287
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7546, Precision@3: 0.6287
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7604, Precision@3: 0.6341
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7604, Precision@3: 0.6341
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7604, Precision@3: 0.6341
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7604, Precision@3: 0.6341
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8410, Precision@3: 0.6971
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8408, Precision@3: 0.6969
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8414, Precision@3: 0.6976
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8410, Precision@3: 0.6971
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8532, Precision@3: 0.7084
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8530, Precision@3: 0.7081
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8528, Precision@3: 0.7079
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8528, Precision@3: 0.7079
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8730, Precision@3: 0.7258
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8736, Precision@3: 0.7262
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8730, Precision@3: 0.7258
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8736, Precision@3: 0.7262
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8762, Precision@3: 0.7284
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8756, Precision@3: 0.7280
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8760, Precision@3: 0.7282
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8753, Precision@3: 0.7278
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7448, Precision@3: 0.6200
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7448, Precision@3: 0.6200
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7448, Precision@3: 0.6200
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7448, Precision@3: 0.6200
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7574, Precision@3: 0.6304
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7574, Precision@3: 0.6304
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7574, Precision@3: 0.6304
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7574, Precision@3: 0.6304
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8519, Precision@3: 0.7077
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8515, Precision@3: 0.7073
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8519, Precision@3: 0.7077
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8515, Precision@3: 0.7073
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8623, Precision@3: 0.7163
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8618, Precision@3: 0.7159
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8626, Precision@3: 0.7163
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8621, Precision@3: 0.7159
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8756, Precision@3: 0.7280
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8753, Precision@3: 0.7278
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8754, Precision@3: 0.7278
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8753, Precision@3: 0.7278
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8756, Precision@3: 0.7286
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8748, Precision@3: 0.7280
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8759, Precision@3: 0.7289
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8748, Precision@3: 0.7280
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7516, Precision@3: 0.6259
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7518, Precision@3: 0.6261
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7516, Precision@3: 0.6259
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7516, Precision@3: 0.6259
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7654, Precision@3: 0.6364
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7654, Precision@3: 0.6364
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7654, Precision@3: 0.6364
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7654, Precision@3: 0.6364
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8592, Precision@3: 0.7146
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8592, Precision@3: 0.7146
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8592, Precision@3: 0.7146
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8592, Precision@3: 0.7146
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8662, Precision@3: 0.7196
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8660, Precision@3: 0.7193
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8665, Precision@3: 0.7198
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8662, Precision@3: 0.7196
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8754, Precision@3: 0.7280
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8747, Precision@3: 0.7274
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8752, Precision@3: 0.7278
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8752, Precision@3: 0.7278
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8756, Precision@3: 0.7280
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8748, Precision@3: 0.7273
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8759, Precision@3: 0.7282
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8745, Precision@3: 0.7271
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7210, Precision@3: 0.5961
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7208, Precision@3: 0.5959
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7210, Precision@3: 0.5961
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7208, Precision@3: 0.5959
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7260, Precision@3: 0.5993
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7260, Precision@3: 0.5993
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7260, Precision@3: 0.5993
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7260, Precision@3: 0.5993
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8040, Precision@3: 0.6621
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8037, Precision@3: 0.6619
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8040, Precision@3: 0.6621
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8037, Precision@3: 0.6619
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8138, Precision@3: 0.6697
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8138, Precision@3: 0.6697
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8140, Precision@3: 0.6699
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8136, Precision@3: 0.6695
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8370, Precision@3: 0.6900
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8364, Precision@3: 0.6894
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8366, Precision@3: 0.6898
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8373, Precision@3: 0.6902
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8329, Precision@3: 0.6863
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8338, Precision@3: 0.6870
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8345, Precision@3: 0.6883
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8346, Precision@3: 0.6878
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7202, Precision@3: 0.5935
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7200, Precision@3: 0.5933
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7202, Precision@3: 0.5935
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7200, Precision@3: 0.5933
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7234, Precision@3: 0.5956
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7232, Precision@3: 0.5954
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7236, Precision@3: 0.5958
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7229, Precision@3: 0.5952
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8128, Precision@3: 0.6682
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8116, Precision@3: 0.6671
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8128, Precision@3: 0.6682
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8123, Precision@3: 0.6678
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8219, Precision@3: 0.6753
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8215, Precision@3: 0.6749
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8219, Precision@3: 0.6751
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8211, Precision@3: 0.6747
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8326, Precision@3: 0.6853
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8338, Precision@3: 0.6861
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8323, Precision@3: 0.6857
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8337, Precision@3: 0.6863
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8311, Precision@3: 0.6844
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8324, Precision@3: 0.6848
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8310, Precision@3: 0.6844
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8327, Precision@3: 0.6857
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7190, Precision@3: 0.5931
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7192, Precision@3: 0.5933
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7190, Precision@3: 0.5931
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7192, Precision@3: 0.5933
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7261, Precision@3: 0.5987
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7261, Precision@3: 0.5987
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7261, Precision@3: 0.5987
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7261, Precision@3: 0.5987
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8108, Precision@3: 0.6665
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8107, Precision@3: 0.6662
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8104, Precision@3: 0.6662
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8100, Precision@3: 0.6658
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8225, Precision@3: 0.6753
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8220, Precision@3: 0.6749
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8227, Precision@3: 0.6755
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8227, Precision@3: 0.6755
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8306, Precision@3: 0.6838
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8305, Precision@3: 0.6833
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8312, Precision@3: 0.6846
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8319, Precision@3: 0.6846
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8254, Precision@3: 0.6788
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8273, Precision@3: 0.6803
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8263, Precision@3: 0.6797
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8282, Precision@3: 0.6812
# Best params for expanded features: {'loss': 'warp', 'no_components': 64, 'learning_rate': 0.05, 'epochs': 50, 'user_alpha': 0.0001, 'item_alpha': 0.0001, 'top3_accuracy': 0.8911597750332838, 'precision@3': 0.7392067}

# %%
print(best_params_base)
print(best_params_expand)
# Out:
# {'loss': 'warp', 'no_components': 32, 'learning_rate': 0.05, 'epochs': 30, 'user_alpha': 0.0001, 'item_alpha': 0.0001, 'top3_accuracy': 0.8537241060810381, 'precision@3': 0.70618016}
# {'loss': 'warp', 'no_components': 64, 'learning_rate': 0.05, 'epochs': 50, 'user_alpha': 0.0001, 'item_alpha': 0.0001, 'top3_accuracy': 0.8911597750332838, 'precision@3': 0.7392067}

# %% [markdown]
# ### Define evaluation functions for test datasets

# %%
def evaluate_lightfm_model(X_train_full, X_test, Y_train_bin, Y_test_bin, feature_set, best_params, label_cols):
    # 1. Feature Selection and Standardization
    X_train_selected = X_train_full[feature_set].copy()
    X_test_selected = X_test[feature_set].copy()
    
    scaler_final = StandardScaler()
    X_train_final = scaler_final.fit_transform(X_train_selected)
    X_test_final = scaler_final.transform(X_test_selected)
    
    # Convert to sparse matrices for efficiency
    user_features_train_final = csr_matrix(X_train_final)
    user_features_test_final = csr_matrix(X_test_final)

    # 2. Prepare Interaction Data
    final_interactions_train = csr_matrix(Y_train_bin.values)
    final_interactions_test = csr_matrix(Y_test_bin.values)
    num_items = len(label_cols)
    final_item_features = identity(num_items, format='csr')

    # 3. Train Final Model with Best Parameters
    model_final = LightFM(
        loss=best_params['loss'],
        no_components=best_params['no_components'],
        learning_rate=best_params['learning_rate'],
        user_alpha=best_params['user_alpha'],
        item_alpha=best_params['item_alpha'],
        random_state=42
    )

    model_final.fit(
        final_interactions_train,
        user_features=user_features_train_final,
        item_features=final_item_features,
        epochs=best_params['epochs'],
        num_threads=4
    )

    # 4. Evaluation Metrics
    # Precision@3
    final_precision = precision_at_k(
        model_final,
        final_interactions_test,
        user_features=user_features_test_final,
        item_features=final_item_features,
        k=3
    ).mean()

    # Custom Top-3 Accuracy
    custom_top3_accuracy = compute_top3_accuracy_for_fold(
        model_final, 
        user_features_test_final, 
        final_interactions_test, 
        final_item_features, 
        k=3
    )

    # 5. Generate Recommendations (Key Part)
    top3_recommendations = {}
    for user_id in range(user_features_test_final.shape[0]):
        # Predict scores for all items
        scores = model_final.predict(
            user_id, 
            np.arange(num_items),
            user_features=user_features_test_final,
            item_features=final_item_features
        )
        
        # Get indices of top 3 highest scores
        top3_indices = np.argsort(-scores)[:3]
        
        # Map indices to product names
        recommended_products = [label_cols[idx] for idx in top3_indices]
        top3_recommendations[user_id] = recommended_products

    return {
        'precision@3': final_precision,
        'custom_top3_accuracy': custom_top3_accuracy
    }, top3_recommendations

# %%
expanded_metrics, expanded_recommendations = evaluate_lightfm_model(X_train_full, X_test, Y_train_bin, Y_test_bin, 
                                                    expanded_features, best_params_expand, label_cols)
print("\nFinal Model Metrics (using expanded features):")
for k, v in expanded_metrics.items():
    print(f"{k}: {v:.4f}")
print("\nTop 3 product recommendations for sample test users:")
for uid in list(expanded_recommendations.keys())[:5]:
    print(f"User {uid}: {expanded_recommendations[uid]}")
# Out:
# Final Model Metrics (using expanded features):
# precision@3: 0.7170
# custom_top3_accuracy: 0.8755
#
# Top 3 product recommendations for sample test users:
# User 0: ['Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card', 'Label_Insurance_Solutions']
# User 1: ['Label_Retention_Efforts', 'Label_Rewards_Credit_Card', 'Label_Travel_Rewards_Card']
# User 2: ['Label_Card_Upgrade', 'Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card']
# User 3: ['Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card', 'Label_Commodity_Investment_Services']
# User 4: ['Label_Retention_Efforts', 'Label_Card_Upgrade', 'Label_Travel_Rewards_Card']

# %% [markdown]
# ### Conclusion: expanded features shows a higher accuracy and precision for the top 3 predictions, as the spending data provides a more hollistic view of the customer's behaviour which could greatly benefits the prediction results.

# %%
# Convert dict to DataFrame
cleaned_dict = {
    user_id: [label.replace('Label_', '') for label in labels]
    for user_id, labels in expanded_recommendations.items()
}

# Convert to DataFrame
df = pd.DataFrame.from_dict(cleaned_dict, orient='index')
df.columns = ['Top1', 'Top2', 'Top3']
# Save to CSV
#df.to_csv("top3_recommendations.csv", index_label='UserID')
df.to_csv('/Users/manyuhaochi/Desktop/DSA3101/archive-2/recommendations.csv', index_label='UserID')
