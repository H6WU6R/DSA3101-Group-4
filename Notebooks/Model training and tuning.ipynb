# %%
import pandas as pd
import numpy as np
import json
from scipy.sparse import csr_matrix, identity
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from lightfm import LightFM
from lightfm.evaluation import precision_at_k, auc_score
from sklearn.metrics import accuracy_score, f1_score
import itertools
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA

# %% [markdown]
# ## Load imputed data

# %%
df_imputed_original = pd.read_csv('../data/processed/imputed_data.csv')

# %% [markdown]
# ## Label Construction
# To train the recommendation system, we need to construct labels that indicating whether a person has purchased certain financial products, which can be derived from the characteristics of demographic data and categorical spending data.
# Joint features are used for label construction, while purchase behavior (e.g., spending in categories like restaurants, utilities, or digital goods) gives insight into interests and lifestyle, it doesn't tell the full story about a customer's financial capacity, needs, or creditworthiness — all of which are critical for financial product targeting.
#
# Median and quantiles for certain features are computed for threshold-based rules.

# %%
income_median = df_imputed_original['yearly_income'].median()
num_cards_median = df_imputed_original['num_credit_cards'].median()
credit_upper = df_imputed_original['credit_score'].quantile(0.75)
income_80 = df_imputed_original['yearly_income'].quantile(0.80)  

# Define relevant spending categories and compute their 75th percentile values
spending_categories = [
    'Retail Stores', 'Restaurants & Eating Places', 'Clothing & Fashion', 
    'Movies & Theaters', 'Sports & Recreational Activities', 'Freight & Trucking', 
    'Medical & Healthcare Services', 'Postal Services - Government Only', 
    'Digital Goods & Computers', 'Telecommunications & Media', 'Utilities & Home Services', 
    'Automotive & Transportation Services', 'Steel & Metal Products', 'Machinery & Tools', 
    'Rail & Bus Transport', 'Hotels & Accommodation', 'Legal & Financial Services'
]
spending_upper = {cat: df_imputed_original[cat].quantile(0.75) for cat in spending_categories}

# %% [markdown]
# ## Rules for label construction

# %%
# 1. Rewards Credit Card:
#    Conditions: (a) any spending category (Retail, Restaurants, Fashion, Movies, Sports) above its upper quantile,
#                (b) credit score above upper quantile,
#                (c) number of credit cards above or equal to median.
def label_rewards_credit_card(row):
    score = 0
    cats = ['Retail Stores', 'Restaurants & Eating Places', 'Clothing & Fashion', 
            'Movies & Theaters', 'Sports & Recreational Activities']
    if any(row[cat] >= spending_upper[cat] for cat in cats):
        score += 1
    if row['credit_score'] >= credit_upper:
        score += 1
    if row['num_credit_cards'] >= num_cards_median:
        score += 1
    return min(score, 3)

# 2. Insurance Solutions:
#    Conditions: (a) any spending category (Freight, Healthcare, Government Postal) above its upper quantile,
#                (b) credit score between median and 80th percentile,
#                (c) yearly income above or equal to median.
def label_insurance_solutions(row):
    score = 0
    cats = ['Freight & Trucking', 'Medical & Healthcare Services', 'Postal Services - Government Only']
    if any(row[cat] >= spending_upper[cat] for cat in cats):
        score += 1
    credit_median = df_imputed_original['credit_score'].quantile(0.50)
    credit_80 = df_imputed_original['credit_score'].quantile(0.80)
    if credit_median < row['credit_score'] <= credit_80:
        score += 1
    if row['yearly_income'] >= income_median:
        score += 1
    return min(score, 3)

# 3. Digital Financing:
#    Conditions: (a) any spending category above its upper quantile,
#                (b) yearly income above median,
#                (c) credit score above upper quantile.
def label_digital_financing(row):
    score = 0
    cats = ['Digital Goods & Computers', 'Telecommunications & Media']
    if any(row[cat] >= spending_upper[cat] for cat in cats):
        score += 1
    if row['yearly_income'] >= income_median:
        score += 1
    if row['credit_score'] >= credit_upper:
        score += 1
    return min(score, 3)

# 4. Home Improvement Loan (loan-related):
#    Conditions: Credit score must exceed upper quantile (else 0),
#                (a) spending in Utilities & Home Services above its upper quantile,
#                (b) yearly income above median.
def label_home_improvement_loan(row):
    score = 0 
    if row['credit_score'] >= credit_upper:
        score += 1
    if row['Utilities & Home Services'] >= spending_upper['Utilities & Home Services']:
        score += 1
    if row['yearly_income'] >= income_median:
        score += 1
    return min(score, 3)

# 5. Auto & Vehicle Financing (loan-related):
#    Conditions: Credit score must exceed upper quantile,
#                (a) spending in Automotive & Transportation Services above its upper quantile,
#                (b) yearly income above median.
def label_auto_vehicle_financing(row):
    score = 0 # Base point for meeting credit requirement
    if row['credit_score'] >= credit_upper:
        score += 1
    if row['Automotive & Transportation Services'] >= spending_upper['Automotive & Transportation Services']:
        score += 1
    if row['yearly_income'] >= income_median:
        score += 1
    return min(score, 3)

# 6. Commodity & Investment Services:
#    Conditions: (a) any spending category (Steel & Metal Products or Machinery & Tools) above its upper quantile,
#                (b) yearly income above median,
#                (c) low total debt relative to income (total_debt < 0.5*yearly_income).
def label_commodity_investment_services(row):
    score = 0
    cats = ['Steel & Metal Products', 'Machinery & Tools']
    if any(row[cat] >= spending_upper[cat] for cat in cats):
        score += 1
    if row['yearly_income'] >= income_80:
        score += 1
    if row['total_debt'] <= 0.5 * row['yearly_income']:
        score += 1
    return min(score, 3)

# 7. Travel Rewards Card:
#    Conditions: (a) any spending category (Rail & Bus Transport or Hotels & Accommodation) above its upper quantile,
#                (b) yearly income above median,
#                (c) number of credit cards above median.
def label_travel_rewards_card(row):
    score = 0
    cats = ['Rail & Bus Transport', 'Hotels & Accommodation']
    if any(row[cat] >= spending_upper[cat] for cat in cats):
        score += 1
    if row['yearly_income'] >= income_median:
        score += 1
    if row['num_credit_cards'] >= num_cards_median:
        score += 1
    return min(score, 3)

# 8. Savings/Investment Plans:
#    Conditions remain unchanged.
def label_savings_investment_plans(row):
    score = 0
    if row['Debit'] >= 1.5 * row['Credit']:
        score += 1
    if row['total_debt'] < 0.5 * row['yearly_income']:
        score += 1
    if row['retirement_age'] - row['current_age'] <= 15:
        score += 1
    return min(score, 3)

# 9. Wealth Management & Savings:
#    Conditions: (a) spending in Legal & Financial Services above its upper quantile,
#                (b) yearly income above median and low total debt,
#                (c) credit score above upper quantile.
def label_wealth_management_savings(row):
    score = 0
    if row['Legal & Financial Services'] >= spending_upper['Legal & Financial Services']:
        score += 1
    if row['yearly_income'] >= income_80 and row['total_debt'] < 0.5 * row['yearly_income']:
        score += 1
    if row['credit_score'] >= credit_upper:
        score += 1
    return min(score, 3)

# %% [markdown]
# ## Computed labels for each financial product

# %%
# Apply label functions to construct new label columns.
df_imputed_original['Label_Rewards_Credit_Card'] = df_imputed_original.apply(label_rewards_credit_card, axis=1)
df_imputed_original['Label_Insurance_Solutions'] = df_imputed_original.apply(label_insurance_solutions, axis=1)
df_imputed_original['Label_Digital_Financing'] = df_imputed_original.apply(label_digital_financing, axis=1)
df_imputed_original['Label_Home_Improvement_Loan'] = df_imputed_original.apply(label_home_improvement_loan, axis=1)
df_imputed_original['Label_Auto_Vehicle_Financing'] = df_imputed_original.apply(label_auto_vehicle_financing, axis=1)
df_imputed_original['Label_Commodity_Investment_Services'] = df_imputed_original.apply(label_commodity_investment_services, axis=1)
df_imputed_original['Label_Travel_Rewards_Card'] = df_imputed_original.apply(label_travel_rewards_card, axis=1)
df_imputed_original['Label_Savings_Investment_Plans'] = df_imputed_original.apply(label_savings_investment_plans, axis=1)
df_imputed_original['Label_Wealth_Management_Savings'] = df_imputed_original.apply(label_wealth_management_savings, axis=1)

print("Sample label counts:")
df_imputed_original[['Label_Rewards_Credit_Card', 'Label_Insurance_Solutions',
                           'Label_Digital_Financing', 'Label_Home_Improvement_Loan',
                           'Label_Auto_Vehicle_Financing', 'Label_Commodity_Investment_Services',
                           'Label_Travel_Rewards_Card', 'Label_Savings_Investment_Plans',
                           'Label_Wealth_Management_Savings']].head()
# Out:
# Sample label counts:
#    Label_Rewards_Credit_Card  Label_Insurance_Solutions  \
# 0                          3                          3
# 1                          2                          1
# 2                          1                          1
# 3                          2                          0
# 4                          2                          2
#
#    Label_Digital_Financing  Label_Home_Improvement_Loan  \
# 0                        3                            3
# 1                        1                            1
# 2                        0                            0
# 3                        1                            0
# 4                        2                            1
#
#    Label_Auto_Vehicle_Financing  Label_Commodity_Investment_Services  \
# 0                             3                                    2
# 1                             1                                    1
# 2                             0                                    0
# 3                             0                                    0
# 4                             1                                    1
#
#    Label_Travel_Rewards_Card  Label_Savings_Investment_Plans  \
# 0                          3                               1
# 1                          3                               1
# 2                          1                               1
# 3                          1                               1
# 4                          2                               1
#
#    Label_Wealth_Management_Savings
# 0                                1
# 1                                0
# 2                                1
# 3                                0
# 4                                1

# %% [markdown]
# ## Save imputed data with label

# %%
df_imputed_original.to_csv('../data/processed/imputed_data_with_label.csv', index=False)

# %% [markdown]
# Computes the top-3 accuracy for a recommender system model.
# This metric evaluates how often the true purchased items for each user appear in the model's top-3 predicted recommendations.
# Users with no recorded purchases are excluded from accuracy computation.
#
# Business Rationale:
# -------------------
# - Reflects realistic scenarios: In real-world recommendation systems, users interact with only a small subset of items.
# - Focuses on meaningful users: Only evaluates users who made actual purchases — avoids inflating performance with inactive users.
# - Top-3 is practical: Many businesses (e.g., e-commerce, fintech) care about whether their top few suggestions convert.
# - Scalable scoring: Gives partial credit (e.g., 0.5) when only some of the true purchases are recommended, reflecting degrees of success.

# %%
def compute_top3_accuracy_for_fold(model, X_val, interactions_val, item_features, k=3):
    num_users = X_val.shape[0]
    top3_acc = []
    users_with_purchases = 0  # Track users who actually bought something
    
    for user_id in range(num_users):
        # Predict scores for all items for this user
        scores = model.predict(user_id, np.arange(interactions_val.shape[1]),
                             user_features=X_val,
                             item_features=item_features)
        
        # Get top k predicted item indices
        top3_indices = np.argsort(-scores)[:k]
        
        # Get true purchased item indices
        true_positives = set(np.where(interactions_val[user_id].toarray().flatten() == 1)[0])
        n_true = len(true_positives)
        
        # Skip users with no purchases (do not count them in accuracy)
        if n_true == 0:
            continue
        
        users_with_purchases += 1
        
        # Case 1: User purchased 3+ items
        if n_true >= 3:
            count = len(set(top3_indices).intersection(true_positives))
            top3_acc.append(count / 3.0)
        
        # Case 2: User purchased exactly 2 items
        elif n_true == 2:
            intersection = set(top3_indices).intersection(true_positives)
            if len(intersection) == 2:
                top3_acc.append(1.0)
            elif len(intersection) == 1:
                top3_acc.append(0.5)
            else:
                top3_acc.append(0)
        
        # Case 3: User purchased exactly 1 item
        elif n_true == 1:
            if top3_indices[0] in true_positives:
                top3_acc.append(1.0)
            elif len(set(top3_indices[1:]).intersection(true_positives)) > 0:
                top3_acc.append(0.5)
            else:
                top3_acc.append(0)
    
    # Return 0 if no users made purchases (edge case)
    if users_with_purchases == 0:
        return 0.0
    
    return np.mean(top3_acc)

# %% [markdown]
# ## Define grid search function for `lightfm`, as it cannot run `GridSearchCV` function directly.
#
# The `grid_search_cv` function performs a comprehensive grid search to optimize hyperparameters for a LightFM recommendation model using 5-fold cross-validation. It first extracts and standardizes user features based on a provided feature list, converting them into a sparse matrix, and then constructs an interaction matrix and an identity-based item features matrix. For each combination of hyperparameters (including loss function, number of components, learning rate, epochs, and regularization parameters), the function splits the training data into folds, applies upsampling on minority classes for each product column in the training interactions, and trains a LightFM model on the imputed data. It then evaluates the model on the validation set using both a standard precision@3 metric and a custom top-3 accuracy function, averaging the scores over the folds. All results are recorded and printed, and the function returns the best hyperparameters based on the highest average top-3 accuracy.

# %%
def grid_search_cv(feature_list, X_train_full, Y_train_bin):
    # Extract the features from X_train_full based on the provided feature list.
    X_train_features = X_train_full[feature_list].copy()
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_features)
    user_features = csr_matrix(X_train_scaled)
    
    # Build the interaction matrix from Y_train_bin.
    interactions = csr_matrix(Y_train_bin.values)
    num_items = interactions.shape[1]
    item_features = identity(num_items, format='csr')
    
    # Define hyperparameter grid.
    param_grid = {
        'loss': ['warp', 'bpr','logistic'],
        'no_components': [16, 32, 64],
        'learning_rate': [0.001, 0.01, 0.05],
        'epochs': [30, 50],
        'user_alpha': [1e-5, 1e-4],
        'item_alpha': [1e-5, 1e-4]
    }
    
    # Set up 5-fold CV.
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    grid_results = []
    upsample_factor = 2

    for loss, no_components, learning_rate, epochs, user_alpha, item_alpha in itertools.product(
        param_grid['loss'],
        param_grid['no_components'],
        param_grid['learning_rate'],
        param_grid['epochs'],
        param_grid['user_alpha'],
        param_grid['item_alpha']
    ):
        fold_top3_acc = []
        fold_prec = []

        for train_idx, val_idx in kf.split(user_features):
            X_train_cv = user_features[train_idx]
            X_val_cv = user_features[val_idx]
            
            # Get the training interactions for this fold.
            fold_train = interactions[train_idx].toarray().astype(float)
            
            # Upsample the minority class for each product column in the training fold.
            for j in range(fold_train.shape[1]):
                pos_count = np.sum(fold_train[:, j] == 1)
                neg_count = np.sum(fold_train[:, j] == 0)
                if pos_count / fold_train.shape[0] < 0.3:
                    fold_train[:, j] = np.where(fold_train[:, j] == 1,
                                                fold_train[:, j] * upsample_factor,
                                                fold_train[:, j])
                elif neg_count / fold_train.shape[0] < 0.3:
                    fold_train[:, j] = np.where(fold_train[:, j] == 0,
                                                fold_train[:, j] * upsample_factor,
                                                fold_train[:, j])
            fold_train_sparse = csr_matrix(fold_train)
            
            # Validation interactions (untouched).
            fold_val = interactions[val_idx].toarray()
            fold_val_sparse = csr_matrix(fold_val)
            
            # Train LightFM on this fold.
            model_cv = LightFM(loss=loss, no_components=no_components,
                               learning_rate=learning_rate,
                               user_alpha=user_alpha,
                               item_alpha=item_alpha,
                               random_state=42)
            model_cv.fit(fold_train_sparse,
                         user_features=X_train_cv,
                         item_features=item_features,
                         epochs=epochs,
                         num_threads=4)
            
            # Standard precision@3.
            prec = precision_at_k(model_cv, fold_val_sparse,
                                  user_features=X_val_cv,
                                  item_features=item_features,
                                  k=3).mean()
            # Compute custom top-3 accuracy using our function.
            top3_acc = compute_top3_accuracy_for_fold(model_cv, X_val_cv, fold_val_sparse, item_features, k=3)
            
            fold_top3_acc.append(top3_acc)
            fold_prec.append(prec)
        
        avg_top3_acc = np.mean(fold_top3_acc)
        avg_prec = np.mean(fold_prec)
        
        grid_results.append({
            'loss': loss,
            'no_components': no_components,
            'learning_rate': learning_rate,
            'epochs': epochs,
            'user_alpha': user_alpha,
            'item_alpha': item_alpha,
            'top3_accuracy': avg_top3_acc,
            'precision@3': avg_prec
        })
        
        print(f"Params: loss={loss}, components={no_components}, "
              f"lr={learning_rate}, epochs={epochs}, user_alpha={user_alpha}, item_alpha={item_alpha} -> "
              f"Top3 Accuracy: {avg_top3_acc:.4f}, Precision@3: {avg_prec:.4f}")
    
    best_params = max(grid_results, key=lambda x: x['top3_accuracy'])
    return best_params, grid_results

# %% [markdown]
# ## Binarize the ordinal labels: define a "positive" interaction if label >= 2.

# %% [markdown]
# ## Feature and Data Splitting Explanation
#
# In the subsequent code snippet, we define three sets of columns: `target_cols` for various spending categories, `feature_cols` for customer and financial attributes used in imputation, and `label_cols` representing the labels for different financial product recommendations. The target variable `Y` is created from the imputed original dataset using the label columns, then binarized by converting values greater than or equal to 2 into 1s, indicating suitability for a particular product. Two user feature sets are prepared: a 'base' set (only using fundamental features) and an 'expanded' set (which includes additional spending categories). These feature sets are stored in a dictionary, and the full dataset is then split into training and testing subsets using a standard 80/20 split, ensuring that the test set remains unmodified for subsequent evaluation of the recommendation model.

# %%
target_cols = ['Automotive & Transportation Services', 'Clothing & Fashion',
       'Digital Goods & Computers', 'Electronics & Appliances',
       'Freight & Trucking', 'Hotels & Accommodation',
       'Legal & Financial Services', 'Machinery & Tools',
       'Medical & Healthcare Services', 'Movies & Theaters',
       'Postal Services - Government Only', 'Rail & Bus Transport',
       'Restaurants & Eating Places', 'Retail Stores',
       'Sports & Recreational Activities', 'Steel & Metal Products',
       'Telecommunications & Media', 'Utilities & Home Services']

# List of feature columns used for imputation
feature_cols = ['current_age', 'retirement_age', 'birth_month', 'gender',
       'latitude', 'longitude', 'yearly_income', 'total_debt', 'credit_score',
       'num_credit_cards', 'Credit', 'Debit', 'Debit (Prepaid)']

label_cols = ['Label_Rewards_Credit_Card', 'Label_Insurance_Solutions',
              'Label_Digital_Financing', 'Label_Home_Improvement_Loan',
              'Label_Auto_Vehicle_Financing', 'Label_Commodity_Investment_Services',
              'Label_Travel_Rewards_Card', 'Label_Savings_Investment_Plans',
              'Label_Wealth_Management_Savings']

Y = df_imputed_original[label_cols].copy()
Y_bin = (Y >= 2).astype(int)

# Prepare user features for tuning.
# Define two feature sets:
base_features = feature_cols.copy()
expanded_features = feature_cols + target_cols  # expanded: include spending categories

# We'll try both feature sets.
feature_sets = {
    'base': base_features,
    'expanded': expanded_features
}

# Split the data into train and test (test set remains unmodified).
X = df_imputed_original.copy()  # full data
X_train_full, X_test, Y_train_bin, Y_test_bin = train_test_split(X, Y_bin, test_size=0.2, random_state=42)

# %% [markdown]
# ## Run both base features and expanded features in hyper-parameter tuning, find best params

# %%
print("\n--- Running grid search for feature set: base ---")
best_params_base, all_results_base = grid_search_cv(base_features, X_train_full, Y_train_bin)
print(f"Best params for base features: {best_params_base}")
print("\n--- Running grid search for feature set: expanded ---")
best_params_expand, all_results_expand = grid_search_cv(expanded_features, X_train_full, Y_train_bin)
print(f"Best params for expanded features: {best_params_expand}")
# Out:
# --- Running grid search for feature set: base ---
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7454, Precision@3: 0.6211
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7452, Precision@3: 0.6211
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7452, Precision@3: 0.6211
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7457, Precision@3: 0.6213
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7446, Precision@3: 0.6208
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7450, Precision@3: 0.6211
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7447, Precision@3: 0.6208
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7444, Precision@3: 0.6206
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8121, Precision@3: 0.6688
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8100, Precision@3: 0.6673
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8127, Precision@3: 0.6695
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8131, Precision@3: 0.6700
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8141, Precision@3: 0.6713
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8131, Precision@3: 0.6703
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8134, Precision@3: 0.6708
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8143, Precision@3: 0.6708
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8131, Precision@3: 0.6713
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8138, Precision@3: 0.6712
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8139, Precision@3: 0.6717
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8188, Precision@3: 0.6755
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8197, Precision@3: 0.6750
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8176, Precision@3: 0.6750
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8172, Precision@3: 0.6737
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8169, Precision@3: 0.6740
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7231, Precision@3: 0.6039
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7231, Precision@3: 0.6039
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7240, Precision@3: 0.6046
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7240, Precision@3: 0.6046
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7311, Precision@3: 0.6116
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7315, Precision@3: 0.6116
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7321, Precision@3: 0.6123
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7318, Precision@3: 0.6121
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8122, Precision@3: 0.6690
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8137, Precision@3: 0.6703
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8105, Precision@3: 0.6678
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8132, Precision@3: 0.6690
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8170, Precision@3: 0.6735
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8155, Precision@3: 0.6723
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8167, Precision@3: 0.6738
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8181, Precision@3: 0.6748
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8169, Precision@3: 0.6742
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8182, Precision@3: 0.6732
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8160, Precision@3: 0.6723
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8186, Precision@3: 0.6752
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8145, Precision@3: 0.6725
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8134, Precision@3: 0.6700
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8169, Precision@3: 0.6728
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8142, Precision@3: 0.6713
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7182, Precision@3: 0.6011
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7186, Precision@3: 0.6016
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7182, Precision@3: 0.6011
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7192, Precision@3: 0.6021
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7271, Precision@3: 0.6066
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7266, Precision@3: 0.6063
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7271, Precision@3: 0.6063
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7258, Precision@3: 0.6053
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8147, Precision@3: 0.6713
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8172, Precision@3: 0.6740
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8120, Precision@3: 0.6698
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8162, Precision@3: 0.6725
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8166, Precision@3: 0.6735
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8161, Precision@3: 0.6728
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8160, Precision@3: 0.6730
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8157, Precision@3: 0.6728
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8150, Precision@3: 0.6720
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8136, Precision@3: 0.6708
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8166, Precision@3: 0.6715
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8136, Precision@3: 0.6718
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8189, Precision@3: 0.6745
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8101, Precision@3: 0.6692
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8152, Precision@3: 0.6725
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8167, Precision@3: 0.6728
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7128, Precision@3: 0.5977
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7128, Precision@3: 0.5977
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7128, Precision@3: 0.5977
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7128, Precision@3: 0.5977
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7107, Precision@3: 0.5962
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7107, Precision@3: 0.5962
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7107, Precision@3: 0.5962
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7104, Precision@3: 0.5960
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7752, Precision@3: 0.6422
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7749, Precision@3: 0.6419
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7752, Precision@3: 0.6422
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7749, Precision@3: 0.6419
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7852, Precision@3: 0.6496
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7850, Precision@3: 0.6494
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7852, Precision@3: 0.6496
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7850, Precision@3: 0.6494
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7913, Precision@3: 0.6570
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7916, Precision@3: 0.6573
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7918, Precision@3: 0.6575
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7912, Precision@3: 0.6570
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7941, Precision@3: 0.6583
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7938, Precision@3: 0.6581
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7944, Precision@3: 0.6586
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7938, Precision@3: 0.6581
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.6957, Precision@3: 0.5836
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6961, Precision@3: 0.5836
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.6953, Precision@3: 0.5833
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.6957, Precision@3: 0.5833
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7015, Precision@3: 0.5900
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7015, Precision@3: 0.5900
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7019, Precision@3: 0.5902
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7019, Precision@3: 0.5902
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7750, Precision@3: 0.6424
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7747, Precision@3: 0.6422
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7750, Precision@3: 0.6424
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7744, Precision@3: 0.6419
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7822, Precision@3: 0.6491
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7819, Precision@3: 0.6491
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7822, Precision@3: 0.6491
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7819, Precision@3: 0.6491
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7955, Precision@3: 0.6600
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7957, Precision@3: 0.6598
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7955, Precision@3: 0.6600
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7953, Precision@3: 0.6598
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7906, Precision@3: 0.6570
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7900, Precision@3: 0.6565
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7903, Precision@3: 0.6568
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7896, Precision@3: 0.6563
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.6856, Precision@3: 0.5781
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6856, Precision@3: 0.5781
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.6856, Precision@3: 0.5781
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.6856, Precision@3: 0.5781
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.6880, Precision@3: 0.5803
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6880, Precision@3: 0.5803
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.6880, Precision@3: 0.5803
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.6880, Precision@3: 0.5803
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7730, Precision@3: 0.6414
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7730, Precision@3: 0.6414
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7730, Precision@3: 0.6414
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7726, Precision@3: 0.6414
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7815, Precision@3: 0.6486
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7812, Precision@3: 0.6484
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7815, Precision@3: 0.6486
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7809, Precision@3: 0.6481
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7885, Precision@3: 0.6546
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7886, Precision@3: 0.6549
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7881, Precision@3: 0.6544
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7890, Precision@3: 0.6551
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7896, Precision@3: 0.6571
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7892, Precision@3: 0.6566
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7896, Precision@3: 0.6571
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7892, Precision@3: 0.6566
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7367, Precision@3: 0.6174
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7367, Precision@3: 0.6174
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7367, Precision@3: 0.6174
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7367, Precision@3: 0.6174
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7178, Precision@3: 0.6015
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7175, Precision@3: 0.6012
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7178, Precision@3: 0.6015
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7178, Precision@3: 0.6015
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7580, Precision@3: 0.6194
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7580, Precision@3: 0.6194
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7580, Precision@3: 0.6194
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7577, Precision@3: 0.6191
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7585, Precision@3: 0.6196
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7586, Precision@3: 0.6196
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7580, Precision@3: 0.6191
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7586, Precision@3: 0.6196
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7650, Precision@3: 0.6266
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7644, Precision@3: 0.6258
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7657, Precision@3: 0.6273
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7638, Precision@3: 0.6256
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7631, Precision@3: 0.6253
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7608, Precision@3: 0.6233
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7620, Precision@3: 0.6238
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7608, Precision@3: 0.6228
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7002, Precision@3: 0.5846
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6998, Precision@3: 0.5843
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7002, Precision@3: 0.5846
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7002, Precision@3: 0.5846
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.6882, Precision@3: 0.5736
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6877, Precision@3: 0.5731
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.6886, Precision@3: 0.5739
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.6882, Precision@3: 0.5736
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7490, Precision@3: 0.6116
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7488, Precision@3: 0.6114
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7500, Precision@3: 0.6124
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7491, Precision@3: 0.6116
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7514, Precision@3: 0.6134
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7512, Precision@3: 0.6131
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7513, Precision@3: 0.6129
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7507, Precision@3: 0.6126
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7637, Precision@3: 0.6246
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7626, Precision@3: 0.6238
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7621, Precision@3: 0.6228
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7625, Precision@3: 0.6233
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7595, Precision@3: 0.6218
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7602, Precision@3: 0.6216
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7600, Precision@3: 0.6216
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7594, Precision@3: 0.6206
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.6882, Precision@3: 0.5734
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6882, Precision@3: 0.5734
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.6882, Precision@3: 0.5734
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.6882, Precision@3: 0.5734
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.6830, Precision@3: 0.5656
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6830, Precision@3: 0.5656
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.6830, Precision@3: 0.5657
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.6827, Precision@3: 0.5654
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7378, Precision@3: 0.6027
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7362, Precision@3: 0.6012
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7382, Precision@3: 0.6029
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7365, Precision@3: 0.6014
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7401, Precision@3: 0.6027
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7392, Precision@3: 0.6019
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7407, Precision@3: 0.6029
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7403, Precision@3: 0.6029
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7599, Precision@3: 0.6218
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7587, Precision@3: 0.6198
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7598, Precision@3: 0.6213
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7585, Precision@3: 0.6196
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7559, Precision@3: 0.6171
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7518, Precision@3: 0.6131
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7554, Precision@3: 0.6169
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7513, Precision@3: 0.6126
# Best params for base features: {'loss': 'warp', 'no_components': 16, 'learning_rate': 0.05, 'epochs': 50, 'user_alpha': 1e-05, 'item_alpha': 1e-05, 'top3_accuracy': 0.8196911919035156, 'precision@3': 0.6749767}
#
# --- Running grid search for feature set: expanded ---
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7366, Precision@3: 0.6143
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7366, Precision@3: 0.6143
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7366, Precision@3: 0.6143
# Params: loss=warp, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7369, Precision@3: 0.6146
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7451, Precision@3: 0.6213
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7438, Precision@3: 0.6203
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7438, Precision@3: 0.6203
# Params: loss=warp, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7442, Precision@3: 0.6205
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8683, Precision@3: 0.7085
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8663, Precision@3: 0.7077
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8645, Precision@3: 0.7057
# Params: loss=warp, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8669, Precision@3: 0.7082
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8700, Precision@3: 0.7097
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8715, Precision@3: 0.7107
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8714, Precision@3: 0.7107
# Params: loss=warp, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8711, Precision@3: 0.7114
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8863, Precision@3: 0.7204
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8834, Precision@3: 0.7179
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8853, Precision@3: 0.7199
# Params: loss=warp, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8837, Precision@3: 0.7191
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8848, Precision@3: 0.7201
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8868, Precision@3: 0.7201
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8828, Precision@3: 0.7184
# Params: loss=warp, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8856, Precision@3: 0.7199
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7271, Precision@3: 0.6126
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7257, Precision@3: 0.6116
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7267, Precision@3: 0.6124
# Params: loss=warp, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7258, Precision@3: 0.6116
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7336, Precision@3: 0.6176
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7336, Precision@3: 0.6173
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7332, Precision@3: 0.6171
# Params: loss=warp, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7324, Precision@3: 0.6163
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8695, Precision@3: 0.7080
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8713, Precision@3: 0.7097
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8735, Precision@3: 0.7114
# Params: loss=warp, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8721, Precision@3: 0.7097
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8755, Precision@3: 0.7129
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8748, Precision@3: 0.7129
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8758, Precision@3: 0.7134
# Params: loss=warp, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8744, Precision@3: 0.7114
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8826, Precision@3: 0.7176
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8856, Precision@3: 0.7191
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8849, Precision@3: 0.7203
# Params: loss=warp, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8870, Precision@3: 0.7201
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8876, Precision@3: 0.7211
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8839, Precision@3: 0.7186
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8875, Precision@3: 0.7214
# Params: loss=warp, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8857, Precision@3: 0.7206
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7240, Precision@3: 0.6094
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7216, Precision@3: 0.6081
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7225, Precision@3: 0.6086
# Params: loss=warp, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7208, Precision@3: 0.6074
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7358, Precision@3: 0.6171
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7367, Precision@3: 0.6178
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7373, Precision@3: 0.6181
# Params: loss=warp, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7362, Precision@3: 0.6176
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8746, Precision@3: 0.7119
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8767, Precision@3: 0.7139
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8723, Precision@3: 0.7102
# Params: loss=warp, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8768, Precision@3: 0.7134
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8781, Precision@3: 0.7139
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8788, Precision@3: 0.7159
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8799, Precision@3: 0.7157
# Params: loss=warp, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8807, Precision@3: 0.7166
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8868, Precision@3: 0.7219
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8864, Precision@3: 0.7206
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8871, Precision@3: 0.7219
# Params: loss=warp, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8854, Precision@3: 0.7196
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8850, Precision@3: 0.7201
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8876, Precision@3: 0.7231
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8866, Precision@3: 0.7209
# Params: loss=warp, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8867, Precision@3: 0.7194
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7227, Precision@3: 0.6062
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7230, Precision@3: 0.6064
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7227, Precision@3: 0.6062
# Params: loss=bpr, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7230, Precision@3: 0.6064
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7226, Precision@3: 0.6069
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7226, Precision@3: 0.6069
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7226, Precision@3: 0.6069
# Params: loss=bpr, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7230, Precision@3: 0.6071
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8314, Precision@3: 0.6843
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8315, Precision@3: 0.6843
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8314, Precision@3: 0.6843
# Params: loss=bpr, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8317, Precision@3: 0.6846
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8426, Precision@3: 0.6918
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8422, Precision@3: 0.6916
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8426, Precision@3: 0.6918
# Params: loss=bpr, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8426, Precision@3: 0.6918
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8690, Precision@3: 0.7114
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8683, Precision@3: 0.7112
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8690, Precision@3: 0.7114
# Params: loss=bpr, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8686, Precision@3: 0.7112
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8651, Precision@3: 0.7095
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8653, Precision@3: 0.7097
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8651, Precision@3: 0.7095
# Params: loss=bpr, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8653, Precision@3: 0.7097
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7029, Precision@3: 0.5935
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7029, Precision@3: 0.5935
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7029, Precision@3: 0.5935
# Params: loss=bpr, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7029, Precision@3: 0.5935
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7088, Precision@3: 0.5959
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7088, Precision@3: 0.5959
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7088, Precision@3: 0.5959
# Params: loss=bpr, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7088, Precision@3: 0.5959
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8387, Precision@3: 0.6898
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8387, Precision@3: 0.6898
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8387, Precision@3: 0.6898
# Params: loss=bpr, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8387, Precision@3: 0.6898
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8478, Precision@3: 0.6965
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8481, Precision@3: 0.6968
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8478, Precision@3: 0.6965
# Params: loss=bpr, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8479, Precision@3: 0.6965
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8669, Precision@3: 0.7097
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8663, Precision@3: 0.7092
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8669, Precision@3: 0.7097
# Params: loss=bpr, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8663, Precision@3: 0.7092
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8677, Precision@3: 0.7102
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8667, Precision@3: 0.7097
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8670, Precision@3: 0.7099
# Params: loss=bpr, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8667, Precision@3: 0.7097
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.6992, Precision@3: 0.5897
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6992, Precision@3: 0.5897
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.6989, Precision@3: 0.5897
# Params: loss=bpr, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.6992, Precision@3: 0.5897
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7054, Precision@3: 0.5940
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7054, Precision@3: 0.5940
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7054, Precision@3: 0.5940
# Params: loss=bpr, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7054, Precision@3: 0.5940
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8402, Precision@3: 0.6910
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8402, Precision@3: 0.6910
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8402, Precision@3: 0.6910
# Params: loss=bpr, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8399, Precision@3: 0.6908
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8498, Precision@3: 0.6978
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8495, Precision@3: 0.6975
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8500, Precision@3: 0.6980
# Params: loss=bpr, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8498, Precision@3: 0.6978
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8606, Precision@3: 0.7057
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8611, Precision@3: 0.7062
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8606, Precision@3: 0.7057
# Params: loss=bpr, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8608, Precision@3: 0.7060
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8664, Precision@3: 0.7089
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8663, Precision@3: 0.7084
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8664, Precision@3: 0.7089
# Params: loss=bpr, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8659, Precision@3: 0.7084
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.6941, Precision@3: 0.5848
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6941, Precision@3: 0.5848
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.6941, Precision@3: 0.5848
# Params: loss=logistic, components=16, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.6941, Precision@3: 0.5848
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7016, Precision@3: 0.5865
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7011, Precision@3: 0.5860
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7011, Precision@3: 0.5860
# Params: loss=logistic, components=16, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7011, Precision@3: 0.5860
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7941, Precision@3: 0.6429
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7942, Precision@3: 0.6429
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7923, Precision@3: 0.6414
# Params: loss=logistic, components=16, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7930, Precision@3: 0.6419
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8016, Precision@3: 0.6476
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8027, Precision@3: 0.6484
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8013, Precision@3: 0.6474
# Params: loss=logistic, components=16, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8009, Precision@3: 0.6471
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8117, Precision@3: 0.6571
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8118, Precision@3: 0.6568
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8131, Precision@3: 0.6583
# Params: loss=logistic, components=16, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8126, Precision@3: 0.6578
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8118, Precision@3: 0.6571
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8135, Precision@3: 0.6583
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8134, Precision@3: 0.6583
# Params: loss=logistic, components=16, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8132, Precision@3: 0.6583
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.6822, Precision@3: 0.5699
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6822, Precision@3: 0.5699
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.6825, Precision@3: 0.5701
# Params: loss=logistic, components=32, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.6820, Precision@3: 0.5696
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.6929, Precision@3: 0.5761
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6927, Precision@3: 0.5759
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.6932, Precision@3: 0.5763
# Params: loss=logistic, components=32, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.6932, Precision@3: 0.5763
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8008, Precision@3: 0.6457
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8011, Precision@3: 0.6459
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8008, Precision@3: 0.6457
# Params: loss=logistic, components=32, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8011, Precision@3: 0.6459
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8063, Precision@3: 0.6506
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8051, Precision@3: 0.6497
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8054, Precision@3: 0.6501
# Params: loss=logistic, components=32, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8051, Precision@3: 0.6499
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8114, Precision@3: 0.6571
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8095, Precision@3: 0.6553
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8132, Precision@3: 0.6583
# Params: loss=logistic, components=32, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8109, Precision@3: 0.6571
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8086, Precision@3: 0.6549
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8068, Precision@3: 0.6539
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8075, Precision@3: 0.6544
# Params: loss=logistic, components=32, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8081, Precision@3: 0.6548
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.6866, Precision@3: 0.5711
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6866, Precision@3: 0.5711
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.6863, Precision@3: 0.5709
# Params: loss=logistic, components=64, lr=0.001, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.6863, Precision@3: 0.5709
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.6981, Precision@3: 0.5766
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.6978, Precision@3: 0.5764
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.6981, Precision@3: 0.5766
# Params: loss=logistic, components=64, lr=0.001, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.6978, Precision@3: 0.5764
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7940, Precision@3: 0.6402
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7925, Precision@3: 0.6387
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7943, Precision@3: 0.6405
# Params: loss=logistic, components=64, lr=0.01, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7922, Precision@3: 0.6385
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7944, Precision@3: 0.6402
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7933, Precision@3: 0.6402
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7947, Precision@3: 0.6404
# Params: loss=logistic, components=64, lr=0.01, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7939, Precision@3: 0.6404
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.8029, Precision@3: 0.6509
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.8020, Precision@3: 0.6501
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.8038, Precision@3: 0.6516
# Params: loss=logistic, components=64, lr=0.05, epochs=30, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.8039, Precision@3: 0.6514
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=1e-05 -> Top3 Accuracy: 0.7968, Precision@3: 0.6467
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=1e-05, item_alpha=0.0001 -> Top3 Accuracy: 0.7978, Precision@3: 0.6474
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=1e-05 -> Top3 Accuracy: 0.7981, Precision@3: 0.6484
# Params: loss=logistic, components=64, lr=0.05, epochs=50, user_alpha=0.0001, item_alpha=0.0001 -> Top3 Accuracy: 0.7995, Precision@3: 0.6494
# Best params for expanded features: {'loss': 'warp', 'no_components': 64, 'learning_rate': 0.05, 'epochs': 50, 'user_alpha': 1e-05, 'item_alpha': 0.0001, 'top3_accuracy': 0.8875735221686695, 'precision@3': 0.723125}

# %%
best_params_base ={'loss': 'warp', 'no_components': 16, 'learning_rate': 0.05, 'epochs': 50, 'user_alpha': 1e-05, 'item_alpha': 1e-05}
best_params_expand = {'loss': 'warp', 'no_components': 64, 'learning_rate': 0.05, 'epochs': 50, 'user_alpha': 1e-05, 'item_alpha': 0.0001}
print(best_params_base)
print(best_params_expand)
# Out:
# {'loss': 'warp', 'no_components': 16, 'learning_rate': 0.05, 'epochs': 50, 'user_alpha': 1e-05, 'item_alpha': 1e-05}
# {'loss': 'warp', 'no_components': 64, 'learning_rate': 0.05, 'epochs': 50, 'user_alpha': 1e-05, 'item_alpha': 0.0001}

# %% [markdown]
# ## Define evaluation functions for test datasets

# %%
def evaluate_lightfm_model(X_train_full, X_test, Y_train_bin, Y_test_bin, feature_set, best_params, label_cols):
    # 1. Feature Selection and Standardization
    X_train_selected = X_train_full[feature_set].copy()
    X_test_selected = X_test[feature_set].copy()
    
    scaler_final = StandardScaler()
    X_train_final = scaler_final.fit_transform(X_train_selected)
    X_test_final = scaler_final.transform(X_test_selected)
    
    # Convert to sparse matrices for efficiency
    user_features_train_final = csr_matrix(X_train_final)
    user_features_test_final = csr_matrix(X_test_final)

    # 2. Prepare Interaction Data
    final_interactions_train = csr_matrix(Y_train_bin.values)
    final_interactions_test = csr_matrix(Y_test_bin.values)
    num_items = len(label_cols)
    final_item_features = identity(num_items, format='csr')

    # 3. Train Final Model with Best Parameters
    model_final = LightFM(
        loss=best_params['loss'],
        no_components=best_params['no_components'],
        learning_rate=best_params['learning_rate'],
        user_alpha=best_params['user_alpha'],
        item_alpha=best_params['item_alpha'],
        random_state=42
    )

    model_final.fit(
        final_interactions_train,
        user_features=user_features_train_final,
        item_features=final_item_features,
        epochs=best_params['epochs'],
        num_threads=4
    )

    # 4. Evaluation Metrics
    # Precision@3
    final_precision = precision_at_k(
        model_final,
        final_interactions_test,
        user_features=user_features_test_final,
        item_features=final_item_features,
        k=3
    ).mean()

    # Custom Top-3 Accuracy
    custom_top3_accuracy = compute_top3_accuracy_for_fold(
        model_final, 
        user_features_test_final, 
        final_interactions_test, 
        final_item_features, 
        k=3
    )

    # 5. Generate Recommendations (Key Part)
    top3_recommendations = {}
    for user_id in range(user_features_test_final.shape[0]):
        # Predict scores for all items
        scores = model_final.predict(
            user_id, 
            np.arange(num_items),
            user_features=user_features_test_final,
            item_features=final_item_features
        )
        
        # Get indices of top 3 highest scores
        top3_indices = np.argsort(-scores)[:3]
        
        # Map indices to product names
        recommended_products = [label_cols[idx] for idx in top3_indices]
        top3_recommendations[user_id] = recommended_products

    return {
        'precision@3': final_precision,
        'custom_top3_accuracy': custom_top3_accuracy
    }, top3_recommendations

# %%
metrics, recommendations = evaluate_lightfm_model(X_train_full, X_test, Y_train_bin, Y_test_bin, 
                                                    base_features, best_params_base, label_cols)
print("\nFinal Model Metrics (using base features):")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nTop 3 product recommendations for sample test users:")
for uid in list(recommendations.keys())[:5]:
    print(f"User {uid}: {recommendations[uid]}")
# Out:
# Final Model Metrics (using base features):
# precision@3: 0.6877
# custom_top3_accuracy: 0.8228
#
# Top 3 product recommendations for sample test users:
# User 0: ['Label_Rewards_Credit_Card', 'Label_Travel_Rewards_Card', 'Label_Digital_Financing']
# User 1: ['Label_Rewards_Credit_Card', 'Label_Travel_Rewards_Card', 'Label_Insurance_Solutions']
# User 2: ['Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card', 'Label_Digital_Financing']
# User 3: ['Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card', 'Label_Insurance_Solutions']
# User 4: ['Label_Digital_Financing', 'Label_Auto_Vehicle_Financing', 'Label_Home_Improvement_Loan']

# %%
metrics, recommendations = evaluate_lightfm_model(X_train_full, X_test, Y_train_bin, Y_test_bin, 
                                                    expanded_features, best_params_expand, label_cols)
print("\nFinal Model Metrics (using expanded features):")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
print("\nTop 3 product recommendations for sample test users:")
for uid in list(recommendations.keys())[:5]:
    print(f"User {uid}: {recommendations[uid]}")
# Out:
# Final Model Metrics (using expanded features):
# precision@3: 0.7367
# custom_top3_accuracy: 0.8844
#
# Top 3 product recommendations for sample test users:
# User 0: ['Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card', 'Label_Insurance_Solutions']
# User 1: ['Label_Travel_Rewards_Card', 'Label_Rewards_Credit_Card', 'Label_Insurance_Solutions']
# User 2: ['Label_Rewards_Credit_Card', 'Label_Travel_Rewards_Card', 'Label_Home_Improvement_Loan']
# User 3: ['Label_Travel_Rewards_Card', 'Label_Commodity_Investment_Services', 'Label_Rewards_Credit_Card']
# User 4: ['Label_Auto_Vehicle_Financing', 'Label_Digital_Financing', 'Label_Home_Improvement_Loan']

# %% [markdown]
# ## Conclusion: expanded features shows a higher accuracy and precision for the top 3 predictions, as the spending data provides a more hollistic view of the customer's behaviour which could greatly benefits the prediction results.

# %%
# Convert dict to DataFrame
cleaned_dict = {
    user_id: [label.replace('Label_', '') for label in labels]
    for user_id, labels in recommendations.items()
}

# Convert to DataFrame
df = pd.DataFrame.from_dict(cleaned_dict, orient='index')
df.columns = ['Top1', 'Top2', 'Top3']
# Save to CSV
df.to_csv('recommendations.csv', index_label='UserID')
